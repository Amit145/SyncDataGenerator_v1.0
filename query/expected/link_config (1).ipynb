# %%
link_product_home_3 =  {
  "product_id": "3",
  "vault_object_id": "link_product_home_3",
  "object_type": "link",
  "target_table": "link_product_home",
  "record_source": "select origin_sys from crm_property_asset_csv",
  "process_order": "2",
  "merge_keys": "product_home_hash_key",
  "build_sql": f"""
with combined AS (
SELECT
    md5(CONCAT(product_ref, origin_sys)) AS product_hash_key,
    md5(CONCAT(property_ref,origin_sys)) AS home_hash_key,
    load_ts,
    origin_sys,
    target_table AS source_tbl_name
  FROM crm_property_asset_csv)
select md5(concat(product_hash_key,home_hash_key,origin_sys)) as product_home_hash_key,
  CAST(load_ts AS timestamp) as load_date,
  origin_sys AS record_source,
  product_hash_key,
  home_hash_key from combined;
""",
  "source_table": "crm_property_asset_csv",
  "created_ts": "2026-06-26 10:00:00.000000",
  "updated_ts": "2026-06-26 10:00:00.000000"
}
####################################################################################################
link_policy_customer_3 =  {
  "product_id": "3",
  "vault_object_id": "link_policy_customer_3",
  "object_type": "link",
  "target_table": "link_policy_customer",
  "record_source": "select origin_sys from crm_policy_register_csv",
  "process_order": "2",
  "merge_keys": "policy_customer_hash_key",
  "build_sql": f"""
with combined AS (
SELECT
    md5(CONCAT(policy_ref, origin_sys)) AS policy_hash_key,
    md5(CONCAT(customer_ref,origin_sys)) AS customer_hash_key,
    load_ts,
    origin_sys,
    target_table AS source_tbl_name
  FROM crm_policy_register_csv)
select md5(concat(policy_hash_key,customer_hash_key,origin_sys)) as policy_customer_hash_key,
  CAST(load_ts AS timestamp) as load_date,
  origin_sys AS record_source,
  customer_hash_key,
  policy_hash_key from combined;
""",
  "source_table": "crm_policy_register_csv",
  "created_ts": "2026-06-26 10:00:00.000000",
  "updated_ts": "2026-06-26 10:00:00.000000"
}
####################################################################################################
link_person_lead_3 =  {
  "product_id": "3",
  "vault_object_id": "link_person_lead_3",
  "object_type": "link",
  "target_table": "link_person_lead",
  "record_source": "select origin_sys from crm_lead_register_csv",
  "process_order": "2",
  "merge_keys": "person_lead_hash_key",
  "build_sql": f"""
with combined AS (
SELECT
    md5(CONCAT(party_ref, origin_sys)) AS person_hash_key,
    md5(CONCAT(lead_ref,origin_sys)) AS lead_hash_key,
    load_ts,
    origin_sys,
    target_table AS source_tbl_name
  FROM crm_lead_register_csv)
select md5(concat(person_hash_key,lead_hash_key,origin_sys)) as person_lead_hash_key,
  CAST(load_ts AS timestamp) as load_date,
  origin_sys AS record_source,
  person_hash_key,
  lead_hash_key from combined;
""",
  "source_table": "crm_lead_register_csv",
  "created_ts": "2026-06-26 10:00:00.000000",
  "updated_ts": "2026-06-26 10:00:00.000000"
}
####################################################################################################
link_quote_person_3 =  {
  "product_id": "3",
  "vault_object_id": "link_quote_person_3",
  "object_type": "link",
  "target_table": "link_quote_person",
  "record_source": "select origin_sys from crm_quote_register_csv",
  "process_order": "2",
  "merge_keys": "quote_person_hash_key",
  "build_sql": f"""
with combined AS (
SELECT
    md5(CONCAT(quote_ref, origin_sys)) AS quote_hash_key,
    md5(CONCAT(party_ref,origin_sys)) AS person_hash_key,
    load_ts,
    origin_sys,
    target_table AS source_tbl_name
  FROM crm_quote_register_csv)
select md5(concat(quote_hash_key,person_hash_key,origin_sys)) as quote_person_hash_key,
  CAST(load_ts AS timestamp) as load_date,
  origin_sys AS record_source,
  quote_hash_key,
  person_hash_key from combined;
""",
  "source_table": "crm_quote_register_csv",
  "created_ts": "2026-06-26 10:00:00.000000",
  "updated_ts": "2026-06-26 10:00:00.000000"
}
####################################################################################################
link_customer_person_3 =  {
  "product_id": "3",
  "vault_object_id": "link_customer_person_3",
  "object_type": "link",
  "target_table": "link_customer_person",
  "record_source": "select origin_sys from crm_customer_portfolio_csv",
  "process_order": "2",
  "merge_keys": "customer_person_hash_key",
  "build_sql": f"""
with combined AS (
SELECT
    md5(CONCAT(customer_ref, origin_sys)) AS customer_hash_key,
    md5(CONCAT(party_ref,origin_sys)) AS person_hash_key,
    load_ts,
    origin_sys,
    target_table AS source_tbl_name
  FROM crm_customer_portfolio_csv)
select md5(concat(customer_hash_key,person_hash_key,origin_sys)) as customer_person_hash_key,
  CAST(load_ts AS timestamp) as load_date,
  origin_sys AS record_source,
  customer_hash_key,
  person_hash_key from combined;
""",
  "source_table": "crm_customer_portfolio_csv",
  "created_ts": "2026-06-26 10:00:00.000000",
  "updated_ts": "2026-06-26 10:00:00.000000"
}
####################################################################################################
link_policy_product_3 =  {
  "product_id": "3",
  "vault_object_id": "link_policy_product_3",
  "object_type": "link",
  "target_table": "link_policy_product",
  "record_source": "select origin_sys from crm_policy_register_csv",
  "process_order": "2",
  "merge_keys": "policy_product_hash_key",
  "build_sql": f"""
with combined AS (
SELECT
    md5(CONCAT(policy_ref, origin_sys)) AS policy_hash_key,
    md5(CONCAT(product_ref,origin_sys)) AS product_hash_key,
    load_ts,
    origin_sys,
    target_table AS source_tbl_name
  FROM crm_policy_register_csv)
select md5(concat(policy_hash_key,product_hash_key,origin_sys)) as policy_customer_hash_key,
  CAST(load_ts AS timestamp) as load_date,
  origin_sys AS record_source,
  policy_hash_key,
  product_hash_key from combined;
""",
  "source_table": "crm_policy_register_csv",
  "created_ts": "2026-06-26 10:00:00.000000",
  "updated_ts": "2026-06-26 10:00:00.000000"
}
####################################################################################################
link_person_consent_3 =  {
  "product_id": "3",
  "vault_object_id": "link_person_consent_3",
  "object_type": "link",
  "target_table": "link_person_consent",
  "record_source": "select origin_sys from crm_consent_snapshot_csv",
  "process_order": "2",
  "merge_keys": "person_consent_hash_key",
  "build_sql": f"""
with combined AS (
SELECT
    md5(CONCAT(party_ref, origin_sys)) AS person_hash_key,
    md5(CONCAT(consent_ref,origin_sys)) AS consent_hash_key,
    load_ts,
    origin_sys,
    target_table AS source_tbl_name
  FROM crm_consent_snapshot_csv)
select md5(concat(person_hash_key,consent_hash_key,origin_sys)) as person_consent_hash_key,
  CAST(load_ts AS timestamp) as load_date,
  origin_sys AS record_source,
  person_hash_key,
  consent_hash_key from combined;
""",
  "source_table": "crm_consent_snapshot_csv",
  "created_ts": "2026-06-26 10:00:00.000000",
  "updated_ts": "2026-06-26 10:00:00.000000"
}
####################################################################################################
link_product_motor_3 =  {
  "product_id": "3",
  "vault_object_id": "link_product_motor_3",
  "object_type": "link",
  "target_table": "link_product_motor",
  "record_source": "select origin_sys from crm_vehicle_asset_csv",
  "process_order": "2",
  "merge_keys": "product_motor_hash_key",
  "build_sql": f"""
with combined AS (
SELECT
    md5(CONCAT(product_ref, origin_sys)) AS product_hash_key,
    md5(CONCAT(vehicle_ref,origin_sys)) AS motor_hash_key,
    load_ts,
    origin_sys,
    target_table AS source_tbl_name
  FROM crm_vehicle_asset_csv)
select md5(concat(product_hash_key,motor_hash_key,origin_sys)) as product_motor_hash_key,
  CAST(load_ts AS timestamp) as load_date,
  origin_sys AS record_source,
  product_hash_key,
  motor_hash_key from combined;
""",
  "source_table": "crm_vehicle_asset_csv",
  "created_ts": "2026-06-26 10:00:00.000000",
  "updated_ts": "2026-06-26 10:00:00.000000"
}
####################################################################################################
link_customer_lead_3 =  {
  "product_id": "3",
  "vault_object_id": "link_customer_lead_3",
  "object_type": "link",
  "target_table": "link_customer_lead",
  "record_source": "select origin_sys from crm_customer_lead_bridge_csv",
  "process_order": "2",
  "merge_keys": "customer_lead_hash_key",
  "build_sql": f"""
with combined AS (
SELECT
    md5(CONCAT(customer_ref, origin_sys)) AS customer_hash_key,
    md5(CONCAT(lead_ref,origin_sys)) AS lead_hash_key,
    load_ts,
    origin_sys,
    target_table AS source_tbl_name
  FROM crm_customer_lead_bridge_csv)
select md5(concat(customer_hash_key,lead_hash_key,origin_sys)) as customer_lead_hash_key,
  CAST(load_ts AS timestamp) as load_date,
  origin_sys AS record_source,
  customer_hash_key,
  lead_hash_key from combined;
""",
  "source_table": "crm_customer_lead_bridge_csv",
  "created_ts": "2026-06-26 10:00:00.000000",
  "updated_ts": "2026-06-26 10:00:00.000000"
}
####################################################################################################
link_quote_product_3 =  {
  "product_id": "3",
  "vault_object_id": "link_quote_product_3",
  "object_type": "link",
  "target_table": "link_quote_product",
  "record_source": "select origin_sys from crm_quote_register_csv",
  "process_order": "2",
  "merge_keys": "quote_product_hash_key",
  "build_sql": f"""
with combined AS (
SELECT
    md5(CONCAT(quote_ref, origin_sys)) AS quote_hash_key,
    md5(CONCAT(product_ref,origin_sys)) AS product_hash_key,
    load_ts,
    origin_sys,
    target_table AS source_tbl_name
  FROM crm_quote_register_csv)
select md5(concat(quote_hash_key,product_hash_key,origin_sys)) as quote_product_hash_key,
  CAST(load_ts AS timestamp) as load_date,
  origin_sys AS record_source,
  quote_hash_key,
  product_hash_key from combined;
""",
  "source_table": "crm_quote_register_csv",
  "created_ts": "2026-06-26 10:00:00.000000",
  "updated_ts": "2026-06-26 10:00:00.000000"
}
####################################################################################################
link_person_marketing_engagement_3 =  {
  "product_id": "3",
  "vault_object_id": "link_person_marketing_engagement_3",
  "object_type": "link",
  "target_table": "link_person_marketing_engagement",
  "record_source": "select origin_sys from crm_campaign_touch_csv",
  "process_order": "2",
  "merge_keys": "person_marketing_engagement_hash_key",
  "build_sql": f"""
with combined AS (
SELECT
    md5(CONCAT(party_ref, origin_sys)) AS person_hash_key,
    md5(CONCAT(engagement_ref,origin_sys)) AS marketing_engagement_hash_key,
    load_ts,
    origin_sys,
    target_table AS source_tbl_name
  FROM crm_campaign_touch_csv)
select md5(concat(person_hash_key,marketing_engagement_hash_key,origin_sys)) as person_marketing_engagement_hash_key,
  CAST(load_ts AS timestamp) as load_date,
  origin_sys AS record_source,
  person_hash_key,
  marketing_engagement_hash_key from combined;
""",
  "source_table": "crm_campaign_touch_csv",
  "created_ts": "2026-06-26 10:00:00.000000",
  "updated_ts": "2026-06-26 10:00:00.000000"
}
####################################################################################################
link_person_identities_3 =  {
  "product_id": "3",
  "vault_object_id": "link_person_identities_3",
  "object_type": "link",
  "target_table": "link_person_identities",
  "record_source": "select origin_sys from crm_identity_registry_csv",
  "process_order": "2",
  "merge_keys": "person_identities_hash_key",
  "build_sql": f"""
with combined AS (
SELECT
    md5(CONCAT(party_ref, origin_sys)) AS person_hash_key,
    md5(CONCAT(identity_ref,origin_sys)) AS identities_hash_key,
    load_ts,
    origin_sys,
    target_table AS source_tbl_name
  FROM crm_identity_registry_csv)
select md5(concat(person_hash_key,identities_hash_key,origin_sys)) as person_identities_hash_key,
  CAST(load_ts AS timestamp) as load_date,
  origin_sys AS record_source,
  person_hash_key,
  identities_hash_key from combined;
""",
  "source_table": "crm_identity_registry_csv",
  "created_ts": "2026-06-26 10:00:00.000000",
  "updated_ts": "2026-06-26 10:00:00.000000"
}
####################################################################################################
link_person_natural_person_3 =  {
  "product_id": "3",
  "vault_object_id": "link_person_natural_person_3",
  "object_type": "link",
  "target_table": "link_person_natural_person",
  "record_source": "select origin_sys from crm_party_master_csv",
  "process_order": "2",
  "merge_keys": "person_natural_person_hash_key",
  "build_sql": f"""
with combined AS (
SELECT
    md5(CONCAT(party_ref, origin_sys)) AS person_hash_key,
    md5(CONCAT(natural_ref,origin_sys)) AS natural_person_hash_key,
    load_ts,
    origin_sys,
    target_table AS source_tbl_name
  FROM crm_party_master_csv where party_kind = 'NATURAL')
select md5(concat(person_hash_key,natural_person_hash_key,origin_sys)) as person_natural_person_hash_key,
  CAST(load_ts AS timestamp) as load_date,
  origin_sys AS record_source,
  person_hash_key,
  natural_person_hash_key from combined;
""",
  "source_table": "crm_party_master_csv",
  "created_ts": "2026-06-26 10:00:00.000000",
  "updated_ts": "2026-06-26 10:00:00.000000"
}
####################################################################################################
link_person_marketing_preference_3 =  {
  "product_id": "3",
  "vault_object_id": "link_person_marketing_preference_3",
  "object_type": "link",
  "target_table": "link_person_marketing_preference",
  "record_source": "select origin_sys from crm_comm_preference_csv",
  "process_order": "2",
  "merge_keys": "person_marketing_preference_hash_key",
  "build_sql": f"""
with combined AS (
SELECT
    md5(CONCAT(party_ref, origin_sys)) AS person_hash_key,
    md5(CONCAT(preference_ref,origin_sys)) AS marketing_preference_hash_key,
    load_ts,
    origin_sys,
    target_table AS source_tbl_name
  FROM crm_comm_preference_csv)
select md5(concat(person_hash_key,marketing_preference_hash_key,origin_sys)) as person_marketing_preference_hash_key,
  CAST(load_ts AS timestamp) as load_date,
  origin_sys AS record_source,
  person_hash_key,
  marketing_preference_hash_key from combined;
""",
  "source_table": "crm_comm_preference_csv",
  "created_ts": "2026-06-26 10:00:00.000000",
  "updated_ts": "2026-06-26 10:00:00.000000"
}
####################################################################################################
link_person_legal_person_3 =  {
  "product_id": "3",
  "vault_object_id": "link_person_legal_person_3",
  "object_type": "link",
  "target_table": "link_person_legal_person",
  "record_source": "select origin_sys from crm_party_master_csv",
  "process_order": "2",
  "merge_keys": "person_legal_person_hash_key",
  "build_sql": f"""
with combined AS (
SELECT
    md5(CONCAT(party_ref, origin_sys)) AS person_hash_key,
    md5(CONCAT(legal_ref,origin_sys)) AS legal_person_hash_key,
    load_ts,
    origin_sys,
    target_table AS source_tbl_name
  FROM crm_party_master_csv WHERE party_kind = 'LEGAL')
select md5(concat(person_hash_key,legal_person_hash_key,origin_sys)) as person_legal_person_hash_key,
  CAST(load_ts AS timestamp) as load_date,
  origin_sys AS record_source,
  person_hash_key,
  legal_person_hash_key from combined;
""",
  "source_table": "crm_party_master_csv",
  "created_ts": "2026-06-26 10:00:00.000000",
  "updated_ts": "2026-06-26 10:00:00.000000"
}
####################################################################################################
link_person_contact_3 =  {
  "product_id": "3",
  "vault_object_id": "link_person_contact_3",
  "object_type": "link",
  "target_table": "link_person_contact",
  "record_source": "select origin_sys from crm_contact_point_csv",
  "process_order": "2",
  "merge_keys": "person_contact_hash_key",
  "build_sql": f"""
with combined AS (
SELECT
    md5(CONCAT(party_ref, origin_sys)) AS person_hash_key,
    md5(CONCAT(contact_ref,origin_sys)) AS contact_hash_key,
    load_ts,
    origin_sys,
    target_table AS source_tbl_name
  FROM crm_contact_point_csv)
select md5(concat(person_hash_key,contact_hash_key,origin_sys)) as person_contact_hash_key,
  CAST(load_ts AS timestamp) as load_date,
  origin_sys AS record_source,
  person_hash_key,
  contact_hash_key from combined;
""",
  "source_table": "crm_contact_point_csv",
  "created_ts": "2026-06-26 10:00:00.000000",
  "updated_ts": "2026-06-26 10:00:00.000000"
}
####################################################################################################
link_person_account_3 =  {
  "product_id": "3",
  "vault_object_id": "link_person_account_3",
  "object_type": "link",
  "target_table": "link_person_account",
  "record_source": "select origin_sys from crm_account_book_csv",
  "process_order": "2",
  "merge_keys": "person_account_hash_key",
  "build_sql": f"""
with combined AS (
SELECT
    md5(CONCAT(party_ref, origin_sys)) AS person_hash_key,
    md5(CONCAT(account_ref,origin_sys)) AS account_hash_key,
    load_ts,
    origin_sys,
    target_table AS source_tbl_name
  FROM crm_account_book_csv)
select md5(concat(person_hash_key,account_hash_key,origin_sys)) as person_account_hash_key,
  CAST(load_ts AS timestamp) as load_date,
  origin_sys AS record_source,
  person_hash_key,
  account_hash_key from combined;
""",
  "source_table": "crm_account_book_csv",
  "created_ts": "2026-06-26 10:00:00.000000",
  "updated_ts": "2026-06-26 10:00:00.000000"
}
####################################################################################################
link_person_home_address_3 =  {
  "product_id": "3",
  "vault_object_id": "link_person_home_address_3",
  "object_type": "link",
  "target_table": "link_person_home_address",
  "record_source": "select origin_sys from crm_address_book_csv",
  "process_order": "2",
  "merge_keys": "person_home_address_hash_key",
  "build_sql": f"""
with combined AS (
SELECT
    md5(CONCAT(party_ref, origin_sys)) AS person_hash_key,
    md5(CONCAT(address_ref,origin_sys)) AS home_address_hash_key,
    load_ts,
    origin_sys,
    target_table AS source_tbl_name
  FROM crm_address_book_csv)
select md5(concat(person_hash_key,home_address_hash_key,origin_sys)) as person_home_address_hash_key,
  CAST(load_ts AS timestamp) as load_date,
  origin_sys AS record_source,
  person_hash_key,
  home_address_hash_key from combined;
""",
  "source_table": "crm_address_book_csv",
  "created_ts": "2026-06-26 10:00:00.000000",
  "updated_ts": "2026-06-26 10:00:00.000000"
}

# %%
link_details = {
    "process_order": "2",
    "status": {
        "link_product_home_3": {"config": link_product_home_3, "is_active": True},
        "link_policy_customer_3": {"config": link_policy_customer_3, "is_active": True},
        "link_person_lead_3": {"config": link_person_lead_3, "is_active": True},
        "link_quote_person_3": {"config": link_quote_person_3, "is_active": True},
        "link_customer_person_3": {"config": link_customer_person_3, "is_active": True},
        "link_policy_product_3": {"config": link_policy_product_3, "is_active": True},
        "link_person_consent_3": {"config": link_person_consent_3, "is_active": True},
        "link_product_motor_3": {"config": link_product_motor_3, "is_active": True},
        "link_customer_lead_3": {"config": link_customer_lead_3, "is_active": True},
        "link_quote_product_3": {"config": link_quote_product_3, "is_active": True},
        "link_person_marketing_engagement_3": {"config": link_person_marketing_engagement_3, "is_active": True},
        "link_person_identities_3": {"config": link_person_identities_3, "is_active": True},
        "link_person_natural_person_3": {"config": link_person_natural_person_3, "is_active": True},
        "link_person_marketing_preference_3": {"config": link_person_marketing_preference_3, "is_active": True},
        "link_person_legal_person_3": {"config": link_person_legal_person_3, "is_active": True},
        "link_person_contact_3": {"config": link_person_contact_3, "is_active": True},
        "link_person_account_3": {"config": link_person_account_3, "is_active": True},
        "link_person_home_address_3": {"config": link_person_home_address_3, "is_active": True}
    }
}

# %%
from collections import OrderedDict

active_configs = []
process_order = link_details["process_order"]
# Use OrderedDict to preserve order as in sat_details["status"]
for k, v in OrderedDict(link_details["status"]).items():
    if v["is_active"]:
        config = v["config"].copy()
        config["process_order"] = str(process_order)
        active_configs.append(config)
df = spark.createDataFrame(active_configs)
display(df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>build_sql</th><th>created_ts</th><th>merge_keys</th><th>object_type</th><th>process_order</th><th>product_id</th><th>record_source</th><th>source_table</th><th>target_table</th><th>updated_ts</th><th>vault_object_id</th></tr></thead><tbody><tr><td>
# with combined AS (
# SELECT
#     md5(CONCAT(product_ref, origin_sys)) AS product_hash_key,
#     md5(CONCAT(property_ref,origin_sys)) AS home_hash_key,
#     load_ts,
#     origin_sys,
#     target_table AS source_tbl_name
#   FROM allianz_coe.bvault_bronze.crm_property_asset_csv)
# ...
