# %%
hub_legal_person_3 =  {
  "product_id": "3",
  "vault_object_id": "hub_legal_person_3",
  "object_type": "hub",
  "target_table": "hub_legal_person",
  "record_source": "select origin_sys from crm_party_master_csv",
  "process_order": "1",
  "merge_keys": "legal_person_hash_key",
  "build_sql": f"""
select md5(CONCAT(legal_ref, origin_sys)) as legal_person_hash_key, legal_ref as legal_person_id, origin_sys as record_source, target_table as source_tbl_name, CAST(pull_ts AS timestamp) as load_date from crm_party_master_csv where party_kind = 'LEGAL'
union all
select md5(CONCAT(person_id, origin_sys)) as legal_person_hash_key, person_id as natural_person_id, origin_sys as record_source, target_table as source_tbl_name, CAST(pull_ts AS timestamp) as load_date from sap_person_db where person_type = 'LEGAL'
""",
  "source_table": "crm_party_master_csv,sap_person_db",
  "created_ts": "2026-06-26 10:00:00.000000",
  "updated_ts": "2026-06-26 10:00:00.000000"
}
####################################################################################################
hub_product_3 =  {
  "product_id": "3",
  "vault_object_id": "hub_product_3",
  "object_type": "hub",
  "target_table": "hub_product",
  "record_source": "select origin_sys from crm_product_catalog_csv",
  "process_order": "1",
  "merge_keys": "product_hash_key",
  "build_sql": f"""
select md5(CONCAT(product_ref, origin_sys)) as product_hash_key, product_ref as product_id, origin_sys as record_source, target_table as source_tbl_name, CAST(pull_ts AS timestamp) as load_date from crm_product_catalog_csv
union all
select md5(CONCAT(product_id, origin_sys)) as product_hash_key, product_id as product_id, origin_sys as record_source, target_table as source_tbl_name, CAST(pull_ts AS timestamp) as load_date from sap_product_db
""",
  "source_table": "crm_product_catalog_csv,sap_product_db",
  "created_ts": "2026-06-26 10:00:00.000000",
  "updated_ts": "2026-06-26 10:00:00.000000"
}
####################################################################################################
hub_natural_person_3 =  {
  "product_id": "3",
  "vault_object_id": "hub_natural_person_3",
  "object_type": "hub",
  "target_table": "hub_natural_person",
  "record_source": "select origin_sys from crm_party_master_csv",
  "process_order": "1",
  "merge_keys": "natural_person_hash_key",
  "build_sql": f"""
select md5(CONCAT(natural_ref, origin_sys)) as natural_person_hash_key, natural_ref as natural_person_id, origin_sys as record_source, target_table as source_tbl_name, CAST(pull_ts AS timestamp) as load_date from crm_party_master_csv where party_kind = 'NATURAL'
union all
select md5(CONCAT(person_id, origin_sys)) as natural_person_hash_key, person_id as natural_person_id, origin_sys as record_source, target_table as source_tbl_name, CAST(pull_ts AS timestamp) as load_date from sap_person_db where person_type = 'NATURAL'
""",
  "source_table": "crm_party_master_csv,sap_person_db",
  "created_ts": "2026-06-26 10:00:00.000000",
  "updated_ts": "2026-06-26 10:00:00.000000"
}
####################################################################################################
hub_lead_3 =  {
  "product_id": "3",
  "vault_object_id": "hub_lead_3",
  "object_type": "hub",
  "target_table": "hub_lead",
  "record_source": "select origin_sys from crm_lead_register_csv",
  "process_order": "1",
  "merge_keys": "lead_hash_key",
  "build_sql": f"""
select distinct md5(concat(lead_ref, origin_sys)) as lead_hash_key, CAST(pull_ts AS timestamp) as load_date, origin_sys as record_source, target_table as source_tbl_name, lead_ref as lead_id 
from crm_lead_register_csv 
""",
  "source_table": "crm_lead_register_csv",
  "created_ts": "2026-06-26 10:00:00.000000",
  "updated_ts": "2026-06-26 10:00:00.000000"
}
####################################################################################################
hub_customer_3 =  {
  "product_id": "3",
  "vault_object_id": "hub_customer_3",
  "object_type": "hub",
  "target_table": "hub_customer",
  "record_source": "select origin_sys from crm_customer_portfolio_csv",
  "process_order": "1",
  "merge_keys": "customer_hash_key",
  "build_sql": f"""
select distinct md5(concat(customer_ref, origin_sys)) as customer_hash_key, CAST(pull_ts AS timestamp) as load_date, origin_sys as record_source, target_table as source_tbl_name, customer_ref as customer_id 
from crm_customer_portfolio_csv 
""",
  "source_table": "crm_customer_portfolio_csv",
  "created_ts": "2026-06-26 10:00:00.000000",
  "updated_ts": "2026-06-26 10:00:00.000000"
}
####################################################################################################
hub_home_address_3 =  {
  "product_id": "3",
  "vault_object_id": "hub_home_address_3",
  "object_type": "hub",
  "target_table": "hub_home_address",
  "record_source": "select origin_sys from crm_address_book_csv",
  "process_order": "1",
  "merge_keys": "address_hash_key",
  "build_sql": f"""
select md5(CONCAT(address_ref, origin_sys)) as address_hash_key, address_ref as address_id, origin_sys as record_source, target_table as source_tbl_name, CAST(pull_ts AS timestamp) as load_date from crm_address_book_csv
union all
select md5(CONCAT(address_id, origin_sys)) as address_hash_key, address_id as insured_object_home_id, origin_sys as record_source, target_table as source_tbl_name, CAST(pull_ts AS timestamp) as load_date from sap_address_db
""",
  "source_table": "crm_address_book_csv,sap_address_db",
  "created_ts": "2026-06-26 10:00:00.000000",
  "updated_ts": "2026-06-26 10:00:00.000000"
}
####################################################################################################
hub_person_3 =  {
  "product_id": "3",
  "vault_object_id": "hub_person_3",
  "object_type": "hub",
  "target_table": "hub_person",
  "record_source": "select origin_sys from crm_party_master_csv",
  "process_order": "1",
  "merge_keys": "person_hash_key",
  "build_sql": f"""
select md5(CONCAT(party_ref, origin_sys)) as person_hash_key, party_ref as person_id, origin_sys as record_source, target_table as source_tbl_name, CAST(pull_ts AS timestamp) as load_date from crm_party_master_csv
union all
select md5(CONCAT(person_id, origin_sys)) as person_hash_key, person_id as person_id, origin_sys as record_source, target_table as source_tbl_name, CAST(pull_ts AS timestamp) as load_date from sap_person_db
""",
  "source_table": "crm_party_master_csv,sap_person_db",
  "created_ts": "2026-06-26 10:00:00.000000",
  "updated_ts": "2026-06-26 10:00:00.000000"
}
####################################################################################################
hub_motor_3 =  {
  "product_id": "3",
  "vault_object_id": "hub_motor_3",
  "object_type": "hub",
  "target_table": "hub_motor",
  "record_source": "select origin_sys from crm_vehicle_asset_csv",
  "process_order": "1",
  "merge_keys": "motor_hash_key",
  "build_sql": f"""
select md5(CONCAT(vehicle_ref, origin_sys)) as motor_hash_key, vehicle_ref as insured_object_motor_id, origin_sys as record_source, target_table as source_tbl_name, CAST(pull_ts AS timestamp) as load_date from crm_vehicle_asset_csv
union all
select md5(CONCAT(motor_id, origin_sys)) as motor_hash_key, motor_id as insured_object_motor_id, origin_sys as record_source, target_table as source_tbl_name, CAST(pull_ts AS timestamp) as load_date from sap_motor_db
""",
  "source_table": "crm_vehicle_asset_csv,sap_motor_db",
  "created_ts": "2026-06-26 10:00:00.000000",
  "updated_ts": "2026-06-26 10:00:00.000000"
}
####################################################################################################
hub_home_3 =  {
  "product_id": "3",
  "vault_object_id": "hub_home_3",
  "object_type": "hub",
  "target_table": "hub_home",
  "record_source": "select origin_sys from crm_property_asset_csv",
  "process_order": "1",
  "merge_keys": "home_hash_key",
  "build_sql": f"""
select md5(CONCAT(property_ref, origin_sys)) as home_hash_key, property_ref as insured_object_home_id, origin_sys as record_source, target_table as source_tbl_name, CAST(pull_ts AS timestamp) as load_date from crm_property_asset_csv
union all
select md5(CONCAT(home_id, origin_sys)) as home_hash_key, home_id as insured_object_home_id, origin_sys as record_source, target_table as source_tbl_name, CAST(pull_ts AS timestamp) as load_date from sap_home_db
""",
  "source_table": "crm_property_asset_csv,sap_home_db",
  "created_ts": "2026-06-26 10:00:00.000000",
  "updated_ts": "2026-06-26 10:00:00.000000"
}
####################################################################################################
hub_policy_3 =  {
  "product_id": "3",
  "vault_object_id": "hub_policy_3",
  "object_type": "hub",
  "target_table": "hub_policy",
  "record_source": "select origin_sys from crm_policy_register_csv",
  "process_order": "1",
  "merge_keys": "policy_hash_key",
  "build_sql": f"""
select distinct md5(concat(policy_ref, origin_sys)) as policy_hash_key, CAST(pull_ts AS timestamp) as load_date, origin_sys as record_source, target_table as source_tbl_name, policy_ref as policy_id from crm_policy_register_csv
""",
  "source_table": "crm_policy_register_csv",
  "created_ts": "2026-06-26 10:00:00.000000",
  "updated_ts": "2026-06-26 10:00:00.000000"
}
####################################################################################################
hub_quote_3 =  {
  "product_id": "3",
  "vault_object_id": "hub_quote_3",
  "object_type": "hub",
  "target_table": "hub_quote",
  "record_source": "select origin_sys from crm_quote_register_csv",
  "process_order": "1",
  "merge_keys": "quote_hash_key",
  "build_sql": f"""
select distinct 
  md5(concat(quote_ref, origin_sys)) as quote_hash_key, 
  CAST(pull_ts AS timestamp) as load_date, 
  origin_sys as record_source,
  target_table as source_tbl_name,
  quote_ref as quote_id 
from crm_quote_register_csv
""",
  "source_table": "crm_quote_register_csv",
  "created_ts": "2026-06-26 10:00:00.000000",
  "updated_ts": "2026-06-26 10:00:00.000000"
}
####################################################################################################
hub_contact_3 =  {
  "product_id": "3",
  "vault_object_id": "hub_contact_3",
  "object_type": "hub",
  "target_table": "hub_contact",
  "record_source": "select origin_sys from crm_contact_point_csv",
  "process_order": "1",
  "merge_keys": "contact_hash_key",
  "build_sql": f"""
select distinct md5(concat(contact_ref, origin_sys)) as contact_hash_key, CAST(pull_ts AS timestamp) as load_date, origin_sys as record_source, target_table as source_tbl_name, contact_ref as contact_id 
from crm_contact_point_csv 
""",
  "source_table": "crm_contact_point_csv",
  "created_ts": "2026-06-26 10:00:00.000000",
  "updated_ts": "2026-06-26 10:00:00.000000"
}
####################################################################################################
hub_consent_3 =  {
  "product_id": "3",
  "vault_object_id": "hub_consent_3",
  "object_type": "hub",
  "target_table": "hub_consent",
  "record_source": "select origin_sys from crm_consent_snapshot_csv",
  "process_order": "1",
  "merge_keys": "consent_hash_key",
  "build_sql": f"""
select distinct md5(concat(consent_ref, origin_sys)) as consent_hash_key, CAST(pull_ts AS timestamp) as load_date, origin_sys as record_source, target_table as source_tbl_name, consent_ref as consent_id 
from crm_consent_snapshot_csv 
""",
  "source_table": "crm_consent_snapshot_csv",
  "created_ts": "2026-06-26 10:00:00.000000",
  "updated_ts": "2026-06-26 10:00:00.000000"
}
####################################################################################################
hub_identities_3 =  {
  "product_id": "3",
  "vault_object_id": "hub_identities_3",
  "object_type": "hub",
  "target_table": "hub_identities",
  "record_source": "select origin_sys from crm_identity_registry_csv",
  "process_order": "1",
  "merge_keys": "identities_hash_key",
  "build_sql": f"""
select distinct md5(concat(identity_ref, origin_sys)) as identities_hash_key, CAST(pull_ts AS timestamp) as load_date, origin_sys as record_source, target_table as source_tbl_name, identity_ref as identities_id
from crm_identity_registry_csv
""",
  "source_table": "crm_identity_registry_csv",
  "created_ts": "2026-06-26 10:00:00.000000",
  "updated_ts": "2026-06-26 10:00:00.000000"
}
####################################################################################################
hub_account_3 =  {
  "product_id": "3",
  "vault_object_id": "hub_account_3",
  "object_type": "hub",
  "target_table": "hub_account",
  "record_source": "select origin_sys from crm_account_book_csv",
  "process_order": "1",
  "merge_keys": "account_hash_key",
  "build_sql": f"""
select distinct 
  md5(concat(account_ref, origin_sys)) as account_hash_key, 
  CAST(pull_ts AS timestamp) as load_date, 
  origin_sys as record_source,
  target_table as source_tbl_name,
  account_ref as account_id 
from crm_account_book_csv 
""",
  "source_table": "crm_account_book_csv",
  "created_ts": "2026-06-26 10:00:00.000000",
  "updated_ts": "2026-06-26 10:00:00.000000"
}
####################################################################################################
hub_marketing_engagement_3 =  {
  "product_id": "3",
  "vault_object_id": "hub_marketing_engagement_3",
  "object_type": "hub",
  "target_table": "hub_marketing_engagement",
  "record_source": "select origin_sys from crm_campaign_touch_csv",
  "process_order": "1",
  "merge_keys": "marketing_engagement_hash_key",
  "build_sql": f"""
select distinct md5(concat(engagement_ref, origin_sys)) as marketing_engagement_hash_key, CAST(pull_ts AS timestamp) as load_date, origin_sys as record_source, target_table as source_tbl_name, engagement_ref as marketing_engagement_id from crm_campaign_touch_csv
""",
  "source_table": "crm_campaign_touch_csv",
  "created_ts": "2026-06-26 10:00:00.000000",
  "updated_ts": "2026-06-26 10:00:00.000000"
}
####################################################################################################
hub_marketing_preference_3 =  {
  "product_id": "3",
  "vault_object_id": "hub_marketing_preference_3",
  "object_type": "hub",
  "target_table": "hub_marketing_preference",
  "record_source": "select origin_sys from crm_comm_preference_csv",
  "process_order": "1",
  "merge_keys": "marketing_preference_hash_key",
  "build_sql": f"""
select distinct md5(concat(preference_ref, origin_sys)) as marketing_preference_hash_key, CAST(pull_ts AS timestamp) as load_date, origin_sys as record_source, target_table as source_tbl_name, preference_ref as marketing_preference_id from crm_comm_preference_csv 
""",
  "source_table": "crm_comm_preference_csv",
  "created_ts": "2026-06-26 10:00:00.000000",
  "updated_ts": "2026-06-26 10:00:00.000000"
}

# %%
hub_details = {
    "process_order": "1",
    "status": {
        "hub_legal_person_3": {"config": hub_legal_person_3, "is_active": True},
        "hub_product_3": {"config": hub_product_3, "is_active": True},
        "hub_consent_3": {"config": hub_consent_3, "is_active": True},
        "hub_identities_3": {"config": hub_identities_3, "is_active": True},
        "hub_account_3": {"config": hub_account_3, "is_active": True},
        "hub_marketing_preference_3": {"config": hub_marketing_preference_3, "is_active": True},
        "hub_person_3": {"config": hub_person_3, "is_active": True},
        "hub_motor_3": {"config": hub_motor_3, "is_active": True},
        "hub_home_3": {"config": hub_home_3, "is_active": True},
        "hub_policy_3": {"config": hub_policy_3, "is_active": True},
        "hub_quote_3": {"config": hub_quote_3, "is_active": True},
        "hub_natural_person_3": {"config": hub_natural_person_3, "is_active": True},
        "hub_lead_3": {"config": hub_lead_3, "is_active": True},
        "hub_contact_3": {"config": hub_contact_3, "is_active": True},
        "hub_customer_3": {"config": hub_customer_3, "is_active": True},
        "hub_home_address_3": {"config": hub_home_address_3, "is_active": True},
        "hub_marketing_engagement_3": {"config": hub_marketing_engagement_3, "is_active": True}
    }
}

# %%
from collections import OrderedDict

active_configs = []
process_order = hub_details["process_order"]
# Use OrderedDict to preserve order as in sat_details["status"]
for k, v in OrderedDict(hub_details["status"]).items():
    if v["is_active"]:
        config = v["config"].copy()
        config["process_order"] = str(process_order)
        active_configs.append(config)
df = spark.createDataFrame(active_configs)
display(df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>build_sql</th><th>created_ts</th><th>merge_keys</th><th>object_type</th><th>process_order</th><th>product_id</th><th>record_source</th><th>source_table</th><th>target_table</th><th>updated_ts</th><th>vault_object_id</th></tr></thead><tbody><tr><td>
# select md5(CONCAT(legal_ref, origin_sys)) as legal_person_hash_key, legal_ref as legal_person_id, origin_sys as record_source, target_table as source_tbl_name, CAST(pull_ts AS timestamp) as load_date from allianz_coe.bvault_bronze.crm_party_master_csv where party_kind = 'LEGAL'
# union all
# ...
