# %%
sat_product_3 =  {
  "product_id": "3",
  "vault_object_id": "sat_product_3",
  "object_type": "sat",
  "target_table": "sat_product",
  "record_source": "select origin_sys from crm_product_catalog_csv",
  "process_order": "3",
  "merge_keys": "product_hash_key|load_date",
  "build_sql": f"""
select distinct md5(concat(product_ref, origin_sys)) as product_hash_key, CAST(load_ts AS timestamp) as load_date, product_line as type, origin_sys as record_source, target_table as source_tbl_name from crm_product_catalog_csv
""",
  "source_table": "crm_product_catalog_csv",
  "created_ts": "2026-06-26 10:00:00.000000",
  "updated_ts": "2026-06-26 10:00:00.000000"
}
####################################################################################################
sat_home_3 =  {
  "product_id": "3",
  "vault_object_id": "sat_home_3",
  "object_type": "sat",
  "target_table": "sat_home",
  "record_source": "select origin_sys from crm_property_asset_csv",
  "process_order": "3",
  "merge_keys": "home_hash_key|load_date",
  "build_sql": f"""
select distinct md5(concat(property_ref, origin_sys)) as home_hash_key, CAST(load_ts AS timestamp) as load_date, wall_material_txt as wall_construction, risk_address_txt as home_risk_address, roof_material_txt as roof_construction, property_type_txt as home_type, property_state_cd as home_state, existing_home_ind as is_existing_home_customer, origin_sys as record_source, target_table as source_tbl_name from crm_property_asset_csv 
""",
  "source_table": "crm_property_asset_csv",
  "created_ts": "2026-06-26 10:00:00.000000",
  "updated_ts": "2026-06-26 10:00:00.000000"
}
####################################################################################################
sat_identities_3 =  {
  "product_id": "3",
  "vault_object_id": "sat_identities_3",
  "object_type": "sat",
  "target_table": "sat_identities",
  "record_source": "select origin_sys from crm_identity_registry_csv",
  "process_order": "3",
  "merge_keys": "identities_hash_key|load_date",
  "build_sql": f"""
select distinct 
  md5(concat(identity_ref, origin_sys)) as identities_hash_key, 
  CAST(load_ts AS timestamp) as load_date, 
  ecid_txt as ecid, 
  hashed_email_txt as hashed_email, 
  origin_sys as record_source,
  target_table as source_tbl_name 
from crm_identity_registry_csv 
where party_ref is not null 
  and trim(cast(party_ref as string)) <> "" 
  and identity_ref is not null 
  and trim(cast(identity_ref as string)) <> "" 
""",
  "source_table": "crm_identity_registry_csv",
  "created_ts": "2026-06-26 10:00:00.000000",
  "updated_ts": "2026-06-26 10:00:00.000000"
}
####################################################################################################
sat_consent_3 =  {
  "product_id": "3",
  "vault_object_id": "sat_consent_3",
  "object_type": "sat",
  "target_table": "sat_consent",
  "record_source": "select origin_sys from crm_consent_snapshot_csv",
  "process_order": "3",
  "merge_keys": "consent_hash_key|load_date",
  "build_sql": f"""
select distinct 
  md5(concat(consent_ref, origin_sys)) as consent_hash_key, 
  CAST(load_ts AS timestamp) as load_date, 
  opt_in_valid_ind as opt_in_validated, 
  opt_in_legit_ind as opt_in_legitimate_interest, 
  origin_sys as record_source,
  target_table as source_tbl_name 
from crm_consent_snapshot_csv 
where party_ref is not null 
  and trim(cast(party_ref as string)) <> "" 
  and consent_ref is not null 
  and trim(cast(consent_ref as string)) <> "" 
""",
  "source_table": "crm_consent_snapshot_csv",
  "created_ts": "2026-06-26 10:00:00.000000",
  "updated_ts": "2026-06-26 10:00:00.000000"
}
####################################################################################################
sat_home_address_3 =  {
  "product_id": "3",
  "vault_object_id": "sat_home_address_3",
  "object_type": "sat",
  "target_table": "sat_home_address",
  "record_source": "select origin_sys from crm_address_book_csv",
  "process_order": "3",
  "merge_keys": "home_address_hash_key|load_date",
  "build_sql": f"""
select distinct 
  md5(concat(address_ref, origin_sys)) as home_address_hash_key, 
  CAST(load_ts AS timestamp) as load_date, 
  street_txt as street, 
  postal_cd as postcode, 
  city_nm as city, 
  state_cd as state, 
  country_cd as country, 
  origin_sys as record_source, 
  target_table as source_tbl_name 
from crm_address_book_csv 
where party_ref is not null 
  and trim(cast(party_ref as string)) <> "" 
  and address_ref is not null 
  and trim(cast(address_ref as string)) <> "" 
""",
  "source_table": "crm_address_book_csv",
  "created_ts": "2026-06-26 10:00:00.000000",
  "updated_ts": "2026-06-26 10:00:00.000000"
}
####################################################################################################
sat_customer_3 =  {
  "product_id": "3",
  "vault_object_id": "sat_customer_3",
  "object_type": "sat",
  "target_table": "sat_customer",
  "record_source": "select origin_sys from crm_customer_portfolio_csv",
  "process_order": "3",
  "merge_keys": "customer_hash_key|load_date",
  "build_sql": f"""
select distinct 
  md5(concat(customer_ref, origin_sys)) as customer_hash_key, 
  CAST(load_ts AS timestamp) as load_date, 
  customer_no as customer_number, 
  customer_status_txt as customer_status, 
  customer_status_reason_txt as customer_status_reason, 
  CAST(customer_since_dt AS timestamp) as customer_since, 
  customer_rating_no as customer_rating, 
  customer_segment_txt as customer_segment, 
  lob_txt as line_of_business, 
  nps_score_no as nps_score, 
  origin_sys as record_source,
  target_table as source_tbl_name 
from crm_customer_portfolio_csv 
where customer_ref is not null 
  and trim(cast(customer_ref as string)) <> "" 
  and party_ref is not null 
  and trim(cast(party_ref as string)) <> "" 
""",
  "source_table": "crm_customer_portfolio_csv",
  "created_ts": "2026-06-26 10:00:00.000000",
  "updated_ts": "2026-06-26 10:00:00.000000"
}
####################################################################################################
sat_motor_3 =  {
  "product_id": "3",
  "vault_object_id": "sat_motor_3",
  "object_type": "sat",
  "target_table": "sat_motor",
  "record_source": "select origin_sys from crm_vehicle_asset_csv",
  "process_order": "3",
  "merge_keys": "motor_hash_key|load_date",
  "build_sql": f"""
select distinct md5(concat(vehicle_ref, origin_sys)) as motor_hash_key, CAST(load_ts AS timestamp) as load_date, auto_decline_ind as auto_decline_vehicle, body_style_txt as body_type, fuel_type_txt as fuel_type, license_status_txt as license_status, existing_motor_ind as is_existing_motor_customer, motor_lapse_cnt as motor_lapsed_policies, garage_address_txt as motor_risk_address, risk_class_cd as risk_class_code, variant_nm as variant, owner_type_txt as vehicle_owner_type, registration_state_cd as vehicle_regstate, vehicle_class_txt as vehicle_class, model_nm as vehicle_model, vehicle_type_txt as vehicle_type, insured_value_amt as motor_sum_insrd, manufacture_yr as vehicle_year, vehicle_age_yrs as vehicle_age, origin_sys as record_source, target_table as source_tbl_name from crm_vehicle_asset_csv 
""",
  "source_table": "crm_vehicle_asset_csv",
  "created_ts": "2026-06-26 10:00:00.000000",
  "updated_ts": "2026-06-26 10:00:00.000000"
}
####################################################################################################
sat_policy_3 =  {
  "product_id": "3",
  "vault_object_id": "sat_policy_3",
  "object_type": "sat",
  "target_table": "sat_policy",
  "record_source": "select origin_sys from crm_policy_register_csv",
  "process_order": "3",
  "merge_keys": "policy_hash_key|load_date",
  "build_sql": f"""
select distinct md5(concat(policy_ref, origin_sys)) as policy_hash_key, CAST(load_ts AS timestamp) as load_date, cover_option_txt as cover_option, declined_claim_cnt as declined_claims, fraud_ind as fraud_flag, gross_amt as gross_revenue, net_amt as net_revenue, active_claim_cnt as number_of_active_claim, previous_claim_cnt as number_of_previous_claim, policy_cycle_no as policy_cicle, CAST(policy_end_dt AS timestamp) as policy_end_date, policy_term_months as policy_length, policy_no as policy_number, CAST(policy_start_dt AS timestamp) as policy_start_date, policy_status_txt as policy_status, renewal_premium_curr as renewal_amount_current_period, renewal_premium_next as renewal_amount_next_period, CAST(renewal_dt AS timestamp) as renewal_date, sales_channel_txt as sales_channel, origin_sys as record_source, target_table as source_tbl_name from crm_policy_register_csv 
""",
  "source_table": "crm_policy_register_csv",
  "created_ts": "2026-06-26 10:00:00.000000",
  "updated_ts": "2026-06-26 10:00:00.000000"
}
####################################################################################################
sat_person_3 =  {
  "product_id": "3",
  "vault_object_id": "sat_person_3",
  "object_type": "sat",
  "target_table": "sat_person",
  "record_source": "select origin_sys from crm_party_master_csv",
  "process_order": "3",
  "merge_keys": "person_hash_key|load_date",
  "build_sql": f"""
select distinct 
  md5(concat(party_ref, origin_sys)) as person_hash_key, 
  CAST(load_ts AS timestamp) as load_date, 
  tenant_cd as tenant_id, 
  lead_ind as is_lead, 
  party_kind as type, 
  paperless_ind as operational_paperless_consent, 
  src_party_ref as source_id, 
  src_party_type as source_type, 
  origin_sys as record_source,
  target_table as source_tbl_name 
from crm_party_master_csv
""",
  "source_table": "crm_party_master_csv",
  "created_ts": "2026-06-26 10:00:00.000000",
  "updated_ts": "2026-06-26 10:00:00.000000"
}
####################################################################################################
sat_quote_3 =  {
  "product_id": "3",
  "vault_object_id": "sat_quote_3",
  "object_type": "sat",
  "target_table": "sat_quote",
  "record_source": "select origin_sys from crm_quote_register_csv",
  "process_order": "3",
  "merge_keys": "quote_hash_key|load_date",
  "build_sql": f"""
select distinct 
  md5(concat(quote_ref, origin_sys)) as quote_hash_key, 
  CAST(load_ts AS timestamp) as load_date, 
  gross_amt as gross_revenue, 
  net_amt as net_revenue, 
  quote_no as quote_number, 
  quote_status_txt as quote_status, 
  renewal_amt_curr as renewal_amt_current_period, 
  renewal_amt_next as renewal_amt_next_period, 
  origin_sys as record_source,
  target_table as source_tbl_name 
from crm_quote_register_csv
""",
  "source_table": "crm_quote_register_csv",
  "created_ts": "2026-06-26 10:00:00.000000",
  "updated_ts": "2026-06-26 10:00:00.000000"
}
####################################################################################################
sat_marketing_engagement_3 =  {
  "product_id": "3",
  "vault_object_id": "sat_marketing_engagement_3",
  "object_type": "sat",
  "target_table": "sat_marketing_engagement",
  "record_source": "select origin_sys from crm_campaign_touch_csv",
  "process_order": "3",
  "merge_keys": "marketing_engagement_hash_key|load_date",
  "build_sql": f"""
select distinct md5(concat(engagement_ref, origin_sys)) as marketing_engagement_hash_key, CAST(load_ts AS timestamp) as load_date, promo_cd as promotion_code, email_opened_ind as opened_email, campaign_status_txt as marketing_status, origin_sys as record_source, target_table as source_tbl_name from crm_campaign_touch_csv where party_ref is not null and trim(cast(party_ref as string)) <> "" and engagement_ref is not null and trim(cast(engagement_ref as string)) <> "" 
""",
  "source_table": "crm_campaign_touch_csv",
  "created_ts": "2026-06-26 10:00:00.000000",
  "updated_ts": "2026-06-26 10:00:00.000000"
}
####################################################################################################
sat_contact_3 =  {
  "product_id": "3",
  "vault_object_id": "sat_contact_3",
  "object_type": "sat",
  "target_table": "sat_contact",
  "record_source": "select origin_sys from crm_contact_point_csv",
  "process_order": "3",
  "merge_keys": "contact_hash_key|load_date",
  "build_sql": f"""
select distinct 
  md5(concat(contact_ref, origin_sys)) as contact_hash_key, 
  CAST(load_ts AS timestamp) as load_date, 
  email_home_txt as personal_email, 
  email_work_txt as work_email, 
  phone_work_txt as work_phone, 
  phone_home_txt as home_phone, 
  origin_sys as record_source,
  target_table as source_tbl_name 
from crm_contact_point_csv 
where party_ref is not null 
  and trim(cast(party_ref as string)) <> "" 
  and contact_ref is not null 
  and trim(cast(contact_ref as string)) <> ""
""",
  "source_table": "crm_contact_point_csv",
  "created_ts": "2026-06-26 10:00:00.000000",
  "updated_ts": "2026-06-26 10:00:00.000000"
}
####################################################################################################
sat_lead_3 =  {
  "product_id": "3",
  "vault_object_id": "sat_lead_3",
  "object_type": "sat",
  "target_table": "sat_lead",
  "record_source": "select origin_sys from crm_lead_register_csv",
  "process_order": "3",
  "merge_keys": "lead_hash_key|load_date",
  "build_sql": f"""
select distinct 
  md5(concat(lead_ref, origin_sys)) as lead_hash_key, 
  CAST(load_ts AS timestamp) as load_date, 
  interest_bucket as interested_level, 
  contact_pref as preferred_contact_method, 
  person_score_no as person_score, 
  person_status_txt as person_status, 
  CAST(converted_dt AS timestamp) as converted_date, 
  origin_sys as record_source,
  target_table as source_tbl_name 
from crm_lead_register_csv 
where party_ref is not null 
  and trim(cast(party_ref as string)) <> "" 
  and lead_ref is not null 
  and trim(cast(lead_ref as string)) <> "" 
""",
  "source_table": "crm_lead_register_csv",
  "created_ts": "2026-06-26 10:00:00.000000",
  "updated_ts": "2026-06-26 10:00:00.000000"
}
####################################################################################################
sat_marketing_preference_3 =  {
  "product_id": "3",
  "vault_object_id": "sat_marketing_preference_3",
  "object_type": "sat",
  "target_table": "sat_marketing_preference",
  "record_source": "select origin_sys from crm_comm_preference_csv",
  "process_order": "3",
  "merge_keys": "marketing_preference_hash_key|load_date",
  "build_sql": f"""
select distinct md5(concat(preference_ref, origin_sys)) as marketing_preference_hash_key, CAST(load_ts AS timestamp) as load_date, sms_ind as sms, email_ind as email, email_sub_ind as email_subscriptions, call_ind as call, any_ind as any, commercial_email_ind as commercial_email, postal_mail_ind as postal_mail, origin_sys as record_source, target_table as source_tbl_name from crm_comm_preference_csv where party_ref is not null and trim(cast(party_ref as string)) <> "" and preference_ref is not null and trim(cast(preference_ref as string)) <> ""
""",
  "source_table": "crm_comm_preference_csv",
  "created_ts": "2026-06-26 10:00:00.000000",
  "updated_ts": "2026-06-26 10:00:00.000000"
}
####################################################################################################
sat_legal_person_3 =  {
  "product_id": "3",
  "vault_object_id": "sat_legal_person_3",
  "object_type": "sat",
  "target_table": "sat_legal_person",
  "record_source": "select origin_sys from crm_party_master_csv",
  "process_order": "3",
  "merge_keys": "legal_person_hash_key|load_date",
  "build_sql": f"""
select distinct 
  md5(concat(legal_ref, origin_sys)) as legal_person_hash_key, 
  CAST(load_ts AS timestamp) as load_date, 
  legal_score_no as person_score, 
  legal_job_title_txt as job_title, 
  legal_src_ref as source_id, 
  legal_src_type as source_type, 
  legal_status_txt as person_status, 
  CAST(lead_conv_dt AS timestamp) as converted_date, 
  CAST(constitution_dt AS timestamp) as date_of_constitution, 
  legal_name as company_name, 
  origin_sys as record_source,
  target_table as source_tbl_name 
from crm_party_master_csv 
where party_kind = 'LEGAL' AND legal_ref is not null and trim(cast(legal_ref as string)) <> ""  
""",
  "source_table": "crm_party_master_csv",
  "created_ts": "2026-06-26 10:00:00.000000",
  "updated_ts": "2026-06-26 10:00:00.000000"
}
####################################################################################################
sat_account_3 =  {
  "product_id": "3",
  "vault_object_id": "sat_account_3",
  "object_type": "sat",
  "target_table": "sat_account",
  "record_source": "select origin_sys from crm_account_book_csv",
  "process_order": "3",
  "merge_keys": "account_hash_key|load_date",
  "build_sql": f"""
select distinct 
  md5(concat(account_ref, origin_sys)) as account_hash_key, 
  CAST(load_ts AS timestamp) as load_date, 
  account_no as account_number, 
  account_type_txt as account_type, 
  CAST(last_access_dt AS timestamp) as account_last_access, 
  CAST(last_change_dt AS timestamp) as account_last_change, 
  account_create_type_txt as account_creation_type, 
  account_status_txt as account_status,
  origin_sys as record_source,
  target_table as source_tbl_name 
from crm_account_book_csv 
where party_ref is not null 
  and trim(cast(party_ref as string)) <> "" 
  and account_ref is not null 
  and trim(cast(account_ref as string)) <> "" 
""",
  "source_table": "crm_account_book_csv",
  "created_ts": "2026-06-26 10:00:00.000000",
  "updated_ts": "2026-06-26 10:00:00.000000"
}
####################################################################################################
sat_natural_person_3 =  {
  "product_id": "3",
  "vault_object_id": "sat_natural_person_3",
  "object_type": "sat",
  "target_table": "sat_natural_person",
  "record_source": "select origin_sys from crm_party_master_csv",
  "process_order": "3",
  "merge_keys": "natural_person_hash_key|load_date",
  "build_sql": f"""
select distinct 
  md5(concat(natural_ref, origin_sys)) as natural_person_hash_key, 
  CAST(load_ts AS timestamp) as load_date, 
  given_nm as first_name, 
  family_nm as last_name, 
  display_nm as full_name, 
  title_txt as courtesy_title, 
  occupation_txt as occupation, 
  CAST(dob AS date) as birth_date, 
  birth_yr as birth_year, 
  nationality_txt as nationality, 
  gender_txt as gender, 
  marital_txt as marital_status, 
  disability_degree as assesed_disability_degree, 
  language_pref as preferred_language, 
  role_txt as role, 
  job_title_txt as job_title, 
  origin_sys as record_source,
  target_table as source_tbl_name 
from crm_party_master_csv
where party_kind = 'NATURAL' AND natural_ref is not null and trim(cast(natural_ref as string)) <> ""
""",
  "source_table": "crm_party_master_csv",
  "created_ts": "2026-06-26 10:00:00.000000",
  "updated_ts": "2026-06-26 10:00:00.000000"
}
####################################################################################################
sat_person_sap_3 =  {
  "product_id": "3",
  "vault_object_id": "sat_person_sap_3",
  "object_type": "sat",
  "target_table": "sat_person_sap",
  "record_source": "select origin_sys from sap_person_db",
  "process_order": "3",
  "merge_keys": "person_hash_key|load_date",
  "build_sql": f"""
select distinct 
  md5(concat(person_id, origin_sys)) as person_hash_key, 
  CAST(load_ts AS timestamp) as load_date, 
  person_type as person_type, 
  email_address as email_address, 
  phone_number as phone_number, 
  origin_sys as record_source,
  target_table as source_tbl_name 
from sap_person_db
""",
  "source_table": "sap_person_db",
  "created_ts": "2026-06-26 10:00:00.000000",
  "updated_ts": "2026-06-26 10:00:00.000000"
}
####################################################################################################
sat_natural_person_sap_3 =  {
  "product_id": "3",
  "vault_object_id": "sat_natural_person_sap_3",
  "object_type": "sat",
  "target_table": "sat_natural_person_sap",
  "record_source": "select origin_sys from sap_person_db",
  "process_order": "3",
  "merge_keys": "natural_person_hash_key|load_date",
  "build_sql": f"""
select distinct 
  md5(concat(person_id, origin_sys)) as natural_person_hash_key, 
  CAST(load_ts AS timestamp) as load_date, 
  first_name as first_name, 
  middle_name as middle_name, 
  last_name as last_name, 
  date_of_birth as date_of_birth, 
  gender as gender, 
  occupation as occupation,  
  origin_sys as record_source,
  target_table as source_tbl_name 
from sap_person_db
where person_type = 'NATURAL'
""",
  "source_table": "sap_person_db",
  "created_ts": "2026-06-26 10:00:00.000000",
  "updated_ts": "2026-06-26 10:00:00.000000"
}
####################################################################################################
sat_legal_person_sap_3 =  {
  "product_id": "3",
  "vault_object_id": "sat_legal_person_sap_3",
  "object_type": "sat",
  "target_table": "sat_legal_person_sap",
  "record_source": "select origin_sys from sap_person_db",
  "process_order": "3",
  "merge_keys": "legal_person_hash_key|load_date",
  "build_sql": f"""
select distinct 
  md5(concat(person_id, origin_sys)) as legal_person_hash_key, 
  CAST(load_ts AS timestamp) as load_date, 
  organization as organization, 
  CAST(org_establishment_date AS DATE) as org_establishment_date, 
  origin_sys as record_source,
  target_table as source_tbl_name 
from sap_person_db
where person_type = 'LEGAL'
""",
  "source_table": "sap_person_db",
  "created_ts": "2026-06-26 10:00:00.000000",
  "updated_ts": "2026-06-26 10:00:00.000000"
}
####################################################################################################
sat_address_sap_3 =  {
  "product_id": "3",
  "vault_object_id": "sat_address_sap_3",
  "object_type": "sat",
  "target_table": "sat_address_sap",
  "record_source": "select origin_sys from sap_address_db",
  "process_order": "3",
  "merge_keys": "address_hash_key|load_date",
  "build_sql": f"""
select distinct 
  md5(concat(address_id, origin_sys)) as address_hash_key, 
  CAST(load_ts AS timestamp) as load_date, 
  address_line_1 as address_line_1, 
  address_line_2 as address_line_2,
  city as city, 
  state as state, 
  country as country, 
  zipcode as zipcode, 
  origin_sys as record_source,
  target_table as source_tbl_name 
from sap_address_db
""",
  "source_table": "sap_address_db",
  "created_ts": "2026-06-26 10:00:00.000000",
  "updated_ts": "2026-06-26 10:00:00.000000"
}
####################################################################################################
sat_motor_sap_3 =  {
  "product_id": "3",
  "vault_object_id": "sat_motor_sap_3",
  "object_type": "sat",
  "target_table": "sat_motor_sap",
  "record_source": "select origin_sys from sap_motor_db",
  "process_order": "3",
  "merge_keys": "motor_hash_key|load_date",
  "build_sql": f"""
select distinct 
  md5(concat(motor_id, origin_sys)) as motor_hash_key, 
  CAST(load_ts AS timestamp) as load_date, 
  motor_class as motor_class,
  motor_model as motor_model,
  motor_type as motor_type,
  fuel_type as fuel_type,
  motor_parked_location as motor_parked_location,
  manufacturing_date as manufacturing_date,
  gear_type as gear_type,
  body_colour as body_colour,
  origin_sys as record_source,
  target_table as source_tbl_name 
from sap_motor_db 
""",
  "source_table": "sap_motor_db",
  "created_ts": "2026-06-26 10:00:00.000000",
  "updated_ts": "2026-06-26 10:00:00.000000"
}
####################################################################################################
sat_home_sap_3 =  {
  "product_id": "3",
  "vault_object_id": "sat_home_sap_3",
  "object_type": "sat",
  "target_table": "sat_home_sap",
  "record_source": "select origin_sys from sap_home_db",
  "process_order": "3",
  "merge_keys": "home_hash_key|load_date",
  "build_sql": f"""
select distinct 
  md5(concat(home_id, origin_sys)) as home_hash_key, 
  CAST(load_ts AS timestamp) as load_date, 
  home_type as home_type,
  home_location as home_location,
  roof_material as roof_material,
  wall_type as wall_type,
  origin_sys as record_source,
  target_table as source_tbl_name 
from sap_home_db 
""",
  "source_table": "sap_home_db",
  "created_ts": "2026-06-26 10:00:00.000000",
  "updated_ts": "2026-06-26 10:00:00.000000"
}
####################################################################################################
sat_product_sap_3 =  {
  "product_id": "3",
  "vault_object_id": "sat_product_sap_3",
  "object_type": "sat",
  "target_table": "sat_product_sap",
  "record_source": "select origin_sys from sap_product_db",
  "process_order": "3",
  "merge_keys": "product_hash_key|load_date",
  "build_sql": f"""
select distinct 
  md5(concat(product_id, origin_sys)) as product_hash_key, 
  CAST(load_ts AS timestamp) as load_date, 
  product_type as product_type,
  product_sub_type as product_sub_type,
  product_name as product_name,
  CAST(product_start_date AS date) as product_start_date,
  line_of_business as line_of_business,
  origin_sys as record_source,
  target_table as source_tbl_name 
from sap_product_db
""",
  "source_table": "sap_product_db",
  "created_ts": "2026-06-26 10:00:00.000000",
  "updated_ts": "2026-06-26 10:00:00.000000"
}

# %%
sat_details = {
    "process_order": "2",
    "status": {
        "sat_product_3": {"config": sat_product_3, "is_active": True},
        "sat_home_3": {"config": sat_home_3, "is_active": True},
        "sat_identities_3": {"config": sat_identities_3, "is_active": True},
        "sat_consent_3": {"config": sat_consent_3, "is_active": True},
        "sat_home_address_3": {"config": sat_home_address_3, "is_active": True},
        "sat_customer_3": {"config": sat_customer_3, "is_active": True},
        "sat_motor_3": {"config": sat_motor_3, "is_active": True},
        "sat_policy_3": {"config": sat_policy_3, "is_active": True},
        "sat_person_3": {"config": sat_person_3, "is_active": True},
        "sat_quote_3": {"config": sat_quote_3, "is_active": True},
        "sat_marketing_engagement_3": {"config": sat_marketing_engagement_3, "is_active": True},
        "sat_contact_3": {"config": sat_contact_3, "is_active": True},
        "sat_lead_3": {"config": sat_lead_3, "is_active": True},
        "sat_marketing_preference_3": {"config": sat_marketing_preference_3, "is_active": True},
        "sat_legal_person_3": {"config": sat_legal_person_3, "is_active": True},
        "sat_account_3": {"config": sat_account_3, "is_active": True},
        "sat_natural_person_3": {"config": sat_natural_person_3, "is_active": True},
        "sat_person_sap_3": {"config": sat_person_sap_3, "is_active": True},
        "sat_natural_person_sap_3": {"config": sat_natural_person_sap_3, "is_active": True},
        "sat_legal_person_sap_3": {"config": sat_legal_person_sap_3, "is_active": True},
        "sat_address_sap_3": {"config": sat_address_sap_3, "is_active": True},
        "sat_motor_sap_3": {"config": sat_motor_sap_3, "is_active": True},
        "sat_home_sap_3": {"config": sat_home_sap_3, "is_active": True},
        "sat_product_sap_3": {"config": sat_product_sap_3, "is_active": True}
    }
}

# %%
from collections import OrderedDict

active_configs = []
process_order = sat_details["process_order"]
# Use OrderedDict to preserve order as in sat_details["status"]
for k, v in OrderedDict(sat_details["status"]).items():
    if v["is_active"]:
        config = v["config"].copy()
        config["process_order"] = str(process_order)
        active_configs.append(config)
df = spark.createDataFrame(active_configs)
display(df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>build_sql</th><th>created_ts</th><th>merge_keys</th><th>object_type</th><th>process_order</th><th>product_id</th><th>record_source</th><th>source_table</th><th>target_table</th><th>updated_ts</th><th>vault_object_id</th></tr></thead><tbody><tr><td>
# select distinct md5(concat(product_ref, origin_sys)) as product_hash_key, CAST(load_ts AS timestamp) as load_date, product_line as type, origin_sys as record_source, target_table as source_tbl_name from allianz_coe.bvault_bronze.crm_product_catalog_csv
# ...
