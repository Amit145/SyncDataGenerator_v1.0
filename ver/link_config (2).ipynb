# %%
link_person_natural_person_9 =  {
  "product_id": "9",
  "vault_object_id": "link_person_natural_person_9",
  "object_type": "link",
  "target_table": "link_person_natural_person",
  "record_source": "select origin_sys from crm_party_master_csv union all select origin_sys from sap_person_db",
  "process_order": "2",
  "merge_keys": "person_natural_person_hash_key",
  "build_sql": f"""
with combined as (
SELECT DISTINCT
    md5(concat( MD5(CONCAT(origin_sys, party_ref)),MD5(CONCAT(origin_sys, natural_ref))))AS person_natural_person_hash_key,
    CAST(pull_ts AS timestamp) AS load_date,
    origin_sys AS record_source,
    MD5(CONCAT(origin_sys, party_ref)) AS person_hash_key,
    MD5(CONCAT(origin_sys, natural_ref)) AS natural_person_hash_key
FROM crm_party_master_csv
WHERE where party_kind = 'NATURAL'
UNION ALL
SELECT DISTINCT
    md5(concat( MD5(CONCAT(origin_sys, person_id)),MD5(CONCAT(origin_sys, person_id))))AS person_natural_person_hash_key,
    CAST(pull_ts AS timestamp) AS load_date,
    origin_sys AS record_source,
    MD5(CONCAT(origin_sys, person_id)) AS person_hash_key,
    MD5(CONCAT(origin_sys, person_id)) AS natural_person_hash_key
FROM sap_person_db 
WHERE person_type = 'NATURAL')
select distinct * from combined;
""",
  "source_table": "crm_party_master_csv, sap_person_db",
  "created_ts": "2026-06-26 10:00:00.000000",
  "updated_ts": "2026-06-26 10:00:00.000000"
}

link_person_legal_person_9 =  {
  "product_id": "9",
  "vault_object_id": "link_person_legal_person_9",
  "object_type": "link",
  "target_table": "link_person_legal_person",
  "record_source": "select origin_sys from crm_party_master_csv union all select origin_sys from sap_person_db",
  "process_order": "2",
  "merge_keys": "person_legal_person_hash_key",
  "build_sql": f"""
with combined as (
SELECT DISTINCT
    md5(concat( MD5(CONCAT(origin_sys, party_ref)),MD5(CONCAT(origin_sys, legal_ref))))AS person_legal_person_hash_key,
    CAST(pull_ts AS timestamp) AS load_date,
    origin_sys AS record_source,
    MD5(CONCAT(origin_sys, party_ref)) AS person_hash_key,
    MD5(CONCAT(origin_sys, legal_ref)) AS legal_person_hash_key
FROM crm_party_master_csv
WHERE where party_kind = 'LEGAL'
UNION ALL
SELECT DISTINCT
    md5(concat( MD5(CONCAT(origin_sys, person_id)),MD5(CONCAT(origin_sys, person_id))))AS person_legal_person_hash_key,
    CAST(pull_ts AS timestamp) AS load_date,
    origin_sys AS record_source,
    MD5(CONCAT(origin_sys, person_id)) AS person_hash_key,
    MD5(CONCAT(origin_sys, person_id)) AS legal_person_hash_key
FROM sap_person_db 
WHERE person_type = 'LEGAL')
select distinct * from combined;
""",
  "source_table": "crm_party_master_csv, sap_person_db",
  "created_ts": "2026-06-26 10:00:00.000000",
  "updated_ts": "2026-06-26 10:00:00.000000"
}

link_person_contact_9 =  {
  "product_id": "9",
  "vault_object_id": "link_person_contact_9",
  "object_type": "link",
  "target_table": "link_person_contact",
  "record_source": "select origin_sys from crm_contact_point_csv",
  "process_order": "2",
  "merge_keys": "person_contact_hash_key",
  "build_sql": f"""
SELECT DISTINCT
    md5(concat( MD5(CONCAT(origin_sys, party_ref)),MD5(CONCAT(origin_sys, contact_ref))))AS person_contact_hash_key,
    CAST(pull_ts AS timestamp) AS load_date,
    origin_sys AS record_source,
    MD5(CONCAT(origin_sys, party_ref)) AS person_hash_key,
    MD5(CONCAT(origin_sys,contact_ref)) AS contact_hash_key
FROM crm_contact_point_csv;
""",
  "source_table": "crm_contact_point_csv",
  "created_ts": "2026-06-26 10:00:00.000000",
  "updated_ts": "2026-06-26 10:00:00.000000"
}

link_person_identities_9 =  {
  "product_id": "9",
  "vault_object_id": "link_person_identities_9",
  "object_type": "link",
  "target_table": "link_person_identities",
  "record_source": "select origin_sys from crm_identity_registry_csv",
  "process_order": "2",
  "merge_keys": "person_identities_hash_key",
  "build_sql": f"""
SELECT DISTINCT
    md5(concat( MD5(CONCAT(origin_sys, party_ref)),MD5(CONCAT(origin_sys, identity_ref))))AS person_identities_hash_key,
    CAST(pull_ts AS timestamp) AS load_date,
    origin_sys AS record_source,
    MD5(CONCAT(origin_sys, party_ref)) AS person_hash_key,
    MD5(CONCAT(origin_sys,identity_ref)) AS identities_hash_key
FROM crm_identity_registry_csv;
""",
  "source_table": "crm_identity_registry_csv",
  "created_ts": "2026-06-26 10:00:00.000000",
  "updated_ts": "2026-06-26 10:00:00.000000"
}

link_person_address_9 =  {
  "product_id": "9",
  "vault_object_id": "link_person_address_9",
  "object_type": "link",
  "target_table": "link_person_address",
  "record_source": "select origin_sys from crm_address_book_csv union all select origin_sys from crm_enhanced_person_relationships_csv union all select origin_sys from sap_address_db",
  "process_order": "2",
  "merge_keys": "person_address_hash_key",
  "build_sql": f"""
with combined as (
SELECT DISTINCT
    md5(concat( MD5(CONCAT(origin_sys, party_ref)),MD5(CONCAT(origin_sys, address_ref))))AS person_address_hash_key,
    CAST(pull_ts AS timestamp) AS load_date,
    origin_sys AS record_source,
    MD5(CONCAT(origin_sys, party_ref)) AS person_hash_key,
    MD5(CONCAT(origin_sys,address_ref)) AS address_hash_key
FROM crm_address_book_csv
UNION ALL
SELECT DISTINCT
    md5(concat( MD5(CONCAT(origin_sys, src_person_id)),MD5(CONCAT(origin_sys, src_address_id))))AS person_address_hash_key,
    CAST(pull_ts AS timestamp) AS load_date,
    origin_sys AS record_source,
    MD5(CONCAT(origin_sys, src_person_id)) AS person_hash_key,
    MD5(CONCAT(origin_sys,src_address_id)) AS address_hash_key
FROM crm_enhanced_person_relationships_csv
WHERE source_extract = 'person_address_bridge.csv'
UNION ALL
SELECT DISTINCT
    md5(concat( MD5(CONCAT(origin_sys, person_id)),MD5(CONCAT(origin_sys, address_id))))AS person_address_hash_key,
    CAST(pull_ts AS timestamp) AS load_date,
    origin_sys AS record_source,
    MD5(CONCAT(origin_sys, person_id)) AS person_hash_key,
    MD5(CONCAT(origin_sys,address_id)) AS address_hash_key
FROM sap_address_db)
select distinct * from combined;
""",
  "source_table": "crm_address_book_csv, crm_enhanced_person_relationships_csv, sap_address_db",
  "created_ts": "2026-06-26 10:00:00.000000",
  "updated_ts": "2026-06-26 10:00:00.000000"
}

link_person_consent_9 =  {
  "product_id": "9",
  "vault_object_id": "link_person_consent_9",
  "object_type": "link",
  "target_table": "link_person_consent",
  "record_source": "select origin_sys from crm_consent_snapshot_csv",
  "process_order": "2",
  "merge_keys": "person_consent_hash_key",
  "build_sql": f"""
SELECT DISTINCT
    md5(concat( MD5(CONCAT(origin_sys, party_ref)),MD5(CONCAT(origin_sys, consent_ref))))AS person_consent_hash_key,
    CAST(pull_ts AS timestamp) AS load_date,
    origin_sys AS record_source,
    MD5(CONCAT(origin_sys, party_ref)) AS person_hash_key,
    MD5(CONCAT(origin_sys,consent_ref)) AS consent_hash_key
FROM crm_consent_snapshot_csv;
""",
  "source_table": "crm_consent_snapshot_csv",
  "created_ts": "2026-06-26 10:00:00.000000",
  "updated_ts": "2026-06-26 10:00:00.000000"
}

link_person_marketing_preference_9 =  {
  "product_id": "9",
  "vault_object_id": "link_person_marketing_preference_9",
  "object_type": "link",
  "target_table": "link_person_marketing_preference",
  "record_source": "select origin_sys from crm_comm_preference_csv",
  "process_order": "2",
  "merge_keys": "person_marketing_preference_hash_key",
  "build_sql": f"""
SELECT DISTINCT
    md5(concat( MD5(CONCAT(origin_sys, party_ref)),MD5(CONCAT(origin_sys, preference_ref))))AS person_marketing_preference_hash_key,
    CAST(pull_ts AS timestamp) AS load_date,
    origin_sys AS record_source,
    MD5(CONCAT(origin_sys, party_ref)) AS person_hash_key,
    MD5(CONCAT(origin_sys,preference_ref)) AS marketing_preference_hash_key
FROM crm_comm_preference_csv;
""",
  "source_table": "crm_comm_preference_csv",
  "created_ts": "2026-06-26 10:00:00.000000",
  "updated_ts": "2026-06-26 10:00:00.000000"
}

link_person_marketing_engagement_9 =  {
  "product_id": "9",
  "vault_object_id": "link_person_marketing_engagement_9",
  "object_type": "link",
  "target_table": "link_person_marketing_engagement",
  "record_source": "select origin_sys from crm_campaign_touch_csv",
  "process_order": "2",
  "merge_keys": "person_marketing_engagement_hash_key",
  "build_sql": f"""
SELECT DISTINCT
    md5(concat( MD5(CONCAT(origin_sys, party_ref)),MD5(CONCAT(origin_sys, engagement_ref))))AS person_marketing_engagement_hash_key,
    CAST(pull_ts AS timestamp) AS load_date,
    origin_sys AS record_source,
    MD5(CONCAT(origin_sys, party_ref)) AS person_hash_key,
    MD5(CONCAT(origin_sys,engagement_ref)) AS marketing_engagement_hash_key
FROM crm_campaign_touch_csv;
""",
  "source_table": "crm_campaign_touch_csv",
  "created_ts": "2026-06-26 10:00:00.000000",
  "updated_ts": "2026-06-26 10:00:00.000000"
}

link_person_lead_9 =  {
  "product_id": "9",
  "vault_object_id": "link_person_lead_9",
  "object_type": "link",
  "target_table": "link_person_lead",
  "record_source": "select origin_sys from crm_lead_register_csv",
  "process_order": "2",
  "merge_keys": "person_lead_hash_key",
  "build_sql": f"""
SELECT DISTINCT
    md5(concat( MD5(CONCAT(origin_sys, party_ref)),MD5(CONCAT(origin_sys, lead_ref))))AS person_lead_hash_key,
    CAST(pull_ts AS timestamp) AS load_date,
    origin_sys AS record_source,
    MD5(CONCAT(origin_sys, party_ref)) AS person_hash_key,
    MD5(CONCAT(origin_sys,lead_ref)) AS lead_hash_key
FROM crm_lead_register_csv;
""",
  "source_table": "crm_lead_register_csv",
  "created_ts": "2026-06-26 10:00:00.000000",
  "updated_ts": "2026-06-26 10:00:00.000000"
}

link_person_account_9 =  {
  "product_id": "9",
  "vault_object_id": "link_person_account_9",
  "object_type": "link",
  "target_table": "link_person_account",
  "record_source": "select origin_sys from crm_account_book_csv",
  "process_order": "2",
  "merge_keys": "person_account_hash_key",
  "build_sql": f"""
SELECT DISTINCT
    md5(concat( MD5(CONCAT(origin_sys, party_ref)),MD5(CONCAT(origin_sys, account_ref))))AS person_account_hash_key,
    CAST(pull_ts AS timestamp) AS load_date,
    origin_sys AS record_source,
    MD5(CONCAT(origin_sys, party_ref)) AS person_hash_key,
    MD5(CONCAT(origin_sys,account_ref)) AS account_hash_key
FROM crm_account_book_csv;
""",
  "source_table": "crm_account_book_csv",
  "created_ts": "2026-06-26 10:00:00.000000",
  "updated_ts": "2026-06-26 10:00:00.000000"
}

link_customer_person_9 =  {
  "product_id": "9",
  "vault_object_id": "link_customer_person_9",
  "object_type": "link",
  "target_table": "link_customer_person",
  "record_source": "select origin_sys from crm_customer_portfolio_csv",
  "process_order": "2",
  "merge_keys": "customer_person_hash_key",
  "build_sql": f"""
SELECT DISTINCT
    md5(concat( MD5(CONCAT(origin_sys, party_ref)),MD5(CONCAT(origin_sys, customer_ref))))AS customer_person_hash_key,
    CAST(pull_ts AS timestamp) AS load_date,
    origin_sys AS record_source,
    MD5(CONCAT(origin_sys, party_ref)) AS person_hash_key,
    MD5(CONCAT(origin_sys,customer_ref)) AS customer_hash_key
FROM crm_customer_portfolio_csv;
""",
  "source_table": "crm_customer_portfolio_csv",
  "created_ts": "2026-06-26 10:00:00.000000",
  "updated_ts": "2026-06-26 10:00:00.000000"
}

link_customer_lead_9 =  {
  "product_id": "9",
  "vault_object_id": "link_customer_lead_9",
  "object_type": "link",
  "target_table": "link_customer_lead",
  "record_source": "select origin_sys from crm_customer_lead_bridge_csv",
  "process_order": "2",
  "merge_keys": "customer_lead_hash_key",
  "build_sql": f"""
SELECT DISTINCT
    md5(concat( MD5(CONCAT(origin_sys, lead_ref)),MD5(CONCAT(origin_sys, customer_ref))))AS customer_lead_hash_key,
    CAST(pull_ts AS timestamp) AS load_date,
    origin_sys AS record_source,
    MD5(CONCAT(origin_sys, lead_ref)) AS lead_hash_key,
    MD5(CONCAT(origin_sys,customer_ref)) AS customer_hash_key
FROM crm_customer_lead_bridge_csv;
""",
  "source_table": "crm_customer_lead_bridge_csv",
  "created_ts": "2026-06-26 10:00:00.000000",
  "updated_ts": "2026-06-26 10:00:00.000000"
}

link_quote_person_9 =  {
  "product_id": "9",
  "vault_object_id": "link_quote_person_9",
  "object_type": "link",
  "target_table": "link_quote_person",
  "record_source": "select origin_sys from crm_quote_register_csv",
  "process_order": "2",
  "merge_keys": "quote_person_hash_key",
  "build_sql": f"""
SELECT DISTINCT
    md5(concat( MD5(CONCAT(origin_sys, party_ref)),MD5(CONCAT(origin_sys, quote_ref))))AS quote_person_hash_key,
    CAST(pull_ts AS timestamp) AS load_date,
    origin_sys AS record_source,
    MD5(CONCAT(origin_sys, party_ref)) AS person_hash_key,
    MD5(CONCAT(origin_sys,quote_ref)) AS quote_hash_key
FROM crm_quote_register_csv;
""",
  "source_table": "crm_quote_register_csv",
  "created_ts": "2026-06-26 10:00:00.000000",
  "updated_ts": "2026-06-26 10:00:00.000000"
}

link_quote_product_9 =  {
  "product_id": "9",
  "vault_object_id": "link_quote_product_9",
  "object_type": "link",
  "target_table": "link_quote_product",
  "record_source": "select origin_sys from crm_quote_register_csv",
  "process_order": "2",
  "merge_keys": "quote_product_hash_key",
  "build_sql": f"""
SELECT DISTINCT
    md5(concat( MD5(CONCAT(origin_sys, product_ref)),MD5(CONCAT(origin_sys, quote_ref))))AS quote_product_hash_key,
    CAST(pull_ts AS timestamp) AS load_date,
    origin_sys AS record_source,
    MD5(CONCAT(origin_sys, product_ref)) AS product_hash_key,
    MD5(CONCAT(origin_sys,quote_ref)) AS quote_hash_key
FROM crm_quote_register_csv;
""",
  "source_table": "crm_quote_register_csv",
  "created_ts": "2026-06-26 10:00:00.000000",
  "updated_ts": "2026-06-26 10:00:00.000000"
}

link_policy_customer_9 =  {
  "product_id": "9",
  "vault_object_id": "link_policy_customer_9",
  "object_type": "link",
  "target_table": "link_policy_customer",
  "record_source": "select origin_sys from crm_policy_register_csv",
  "process_order": "2",
  "merge_keys": "policy_customer_hash_key",
  "build_sql": f"""
SELECT DISTINCT
    md5(concat( MD5(CONCAT(origin_sys, policy_ref)),MD5(CONCAT(origin_sys, customer_ref))))AS policy_customer_hash_key,
    CAST(pull_ts AS timestamp) AS load_date,
    origin_sys AS record_source,
    MD5(CONCAT(origin_sys, policy_ref)) AS policy_hash_key,
    MD5(CONCAT(origin_sys,customer_ref)) AS customer_hash_key
FROM crm_policy_register_csv;
""",
  "source_table": "crm_policy_register_csv",
  "created_ts": "2026-06-26 10:00:00.000000",
  "updated_ts": "2026-06-26 10:00:00.000000"
}

link_policy_product_9 =  {
  "product_id": "9",
  "vault_object_id": "link_policy_product_9",
  "object_type": "link",
  "target_table": "link_policy_product",
  "record_source": "select origin_sys from crm_policy_register_csv union all select origin_sys from sap_home_db union all select origin_sys from sap_motor_db",
  "process_order": "2",
  "merge_keys": "policy_product_hash_key",
  "build_sql": f"""
with combined as (
SELECT DISTINCT
    md5(concat( MD5(CONCAT(origin_sys, policy_ref)),MD5(CONCAT(origin_sys, product_ref))))AS policy_product_hash_key,
    CAST(pull_ts AS timestamp) AS load_date,
    origin_sys AS record_source,
    MD5(CONCAT(origin_sys, policy_ref)) AS policy_hash_key,
    MD5(CONCAT(origin_sys, product_ref)) AS product_hash_key
FROM crm_policy_register_csv
UNION ALL
SELECT DISTINCT
    md5(concat( MD5(CONCAT(origin_sys, policy_id)),MD5(CONCAT(origin_sys, product_id))))AS policy_product_hash_key,
    CAST(pull_ts AS timestamp) AS load_date,
    origin_sys AS record_source,
    MD5(CONCAT(origin_sys, policy_id)) AS policy_hash_key,
    MD5(CONCAT(origin_sys, product_id)) AS product_hash_key
FROM sap_home_db
UNION ALL
SELECT DISTINCT
    md5(concat( MD5(CONCAT(origin_sys, policy_id)),MD5(CONCAT(origin_sys, product_id))))AS policy_product_hash_key,
    CAST(pull_ts AS timestamp) AS load_date,
    origin_sys AS record_source,
    MD5(CONCAT(origin_sys, policy_id)) AS policy_hash_key,
    MD5(CONCAT(origin_sys, product_id)) AS product_hash_key
FROM sap_motor_db)
select distinct * from combined;
""",
  "source_table": "crm_policy_register_csv, sap_home_db, sap_motor_db",
  "created_ts": "2026-06-26 10:00:00.000000",
  "updated_ts": "2026-06-26 10:00:00.000000"
}

link_policy_quote_9 =  {
  "product_id": "9",
  "vault_object_id": "link_policy_quote_9",
  "object_type": "link",
  "target_table": "link_policy_quote",
  "record_source": "select origin_sys from crm_policy_register_csv union all select origin_sys from crm_enhanced_policy_relationships_csv",
  "process_order": "2",
  "merge_keys": "policy_quote_hash_key",
  "build_sql": f"""
with combined as (
SELECT DISTINCT
    md5(concat( MD5(CONCAT(origin_sys, policy_ref)),MD5(CONCAT(origin_sys, quote_ref))))AS policy_quote_hash_key,
    CAST(pull_ts AS timestamp) AS load_date,
    origin_sys AS record_source,
    MD5(CONCAT(origin_sys, policy_ref)) AS policy_hash_key,
    MD5(CONCAT(origin_sys, quote_ref)) AS quote_hash_key
FROM crm_policy_register_csv
UNION ALL
SELECT DISTINCT
    md5(concat( MD5(CONCAT(origin_sys, src_policy_id)),MD5(CONCAT(origin_sys, src_quote_id))))AS policy_quote_hash_key,
    CAST(pull_ts AS timestamp) AS load_date,
    origin_sys AS record_source,
    MD5(CONCAT(origin_sys, src_policy_id)) AS policy_hash_key,
    MD5(CONCAT(origin_sys, src_quote_id)) AS quote_hash_key
FROM crm_enhanced_policy_relationships_csv where source_extract = 'policy_quote_bridge.csv')
select distinct * from combined;
""",
  "source_table": "crm_policy_register_csv, crm_enhanced_policy_relationships_csv",
  "created_ts": "2026-06-26 10:00:00.000000",
  "updated_ts": "2026-06-26 10:00:00.000000"
}

link_broker_person_9 =  {
  "product_id": "9",
  "vault_object_id": "link_broker_person_9",
  "object_type": "link",
  "target_table": "link_broker_person",
  "record_source": "select origin_sys from crm_enhanced_person_relationships_csv",
  "process_order": "2",
  "merge_keys": "broker_person_hash_key",
  "build_sql": f"""
SELECT DISTINCT
    md5(concat( MD5(CONCAT(origin_sys, src_agent_id)),MD5(CONCAT(origin_sys, src_person_id))))AS broker_person_hash_key,
    CAST(pull_ts AS timestamp) AS load_date,
    origin_sys AS record_source,
    MD5(CONCAT(origin_sys, src_agent_id)) AS broker_hash_key,
    MD5(CONCAT(origin_sys, src_person_id)) AS person_hash_key
FROM crm_enhanced_person_relationships_csv
WHERE source_extract = 'broker_person_bridge.csv';
""",
  "source_table": "crm_enhanced_person_relationships_csv",
  "created_ts": "2026-06-26 10:00:00.000000",
  "updated_ts": "2026-06-26 10:00:00.000000"
}

link_person_campaign_9 =  {
  "product_id": "9",
  "vault_object_id": "link_person_campaign_9",
  "object_type": "link",
  "target_table": "link_person_campaign",
  "record_source": "select origin_sys from crm_enhanced_person_relationships_csv",
  "process_order": "2",
  "merge_keys": "person_campaign_hash_key",
  "build_sql": f"""
SELECT DISTINCT
    md5(concat( MD5(CONCAT(origin_sys, src_person_id)),MD5(CONCAT(origin_sys, src_campaign_id))))AS person_campaign_hash_key,
    CAST(pull_ts AS timestamp) AS load_date,
    origin_sys AS record_source,
    MD5(CONCAT(origin_sys, src_person_id)) AS person_hash_key,
    MD5(CONCAT(origin_sys, src_campaign_id)) AS campaign_hash_key
FROM crm_enhanced_person_relationships_csv
WHERE source_extract = 'person_campaign_bridge.csv';
""",
  "source_table": "crm_enhanced_person_relationships_csv",
  "created_ts": "2026-06-26 10:00:00.000000",
  "updated_ts": "2026-06-26 10:00:00.000000"
}

link_claim_policy_9 =  {
  "product_id": "9",
  "vault_object_id": "link_claim_policy_9",
  "object_type": "link",
  "target_table": "link_claim_policy",
  "record_source": "select origin_sys from crm_enhanced_policy_relationships_csv",
  "process_order": "2",
  "merge_keys": "claim_policy_hash_key",
  "build_sql": f"""
SELECT DISTINCT
    md5(concat( MD5(CONCAT(origin_sys, src_claim_id)),MD5(CONCAT(origin_sys, src_policy_id))))AS claim_policy_hash_key,
    CAST(pull_ts AS timestamp) AS load_date,
    origin_sys AS record_source,
    MD5(CONCAT(origin_sys, src_claim_id)) AS claim_hash_key,
    MD5(CONCAT(origin_sys, src_policy_id)) AS policy_hash_key
FROM crm_enhanced_policy_relationships_csv
WHERE source_extract = 'claim_policy_bridge.csv';
""",
  "source_table": "crm_enhanced_policy_relationships_csv",
  "created_ts": "2026-06-26 10:00:00.000000",
  "updated_ts": "2026-06-26 10:00:00.000000"
}

link_complaint_policy_9 =  {
  "product_id": "9",
  "vault_object_id": "link_complaint_policy_9",
  "object_type": "link",
  "target_table": "link_complaint_policy",
  "record_source": "select origin_sys from crm_enhanced_policy_relationships_csv",
  "process_order": "2",
  "merge_keys": "complaint_policy_hash_key",
  "build_sql": f"""
SELECT DISTINCT
    md5(concat( MD5(CONCAT(origin_sys, src_complaint_id)),MD5(CONCAT(origin_sys, src_policy_id))))AS complaint_policy_hash_key,
    CAST(pull_ts AS timestamp) AS load_date,
    origin_sys AS record_source,
    MD5(CONCAT(origin_sys, src_complaint_id)) AS complaint_hash_key,
    MD5(CONCAT(origin_sys, src_policy_id)) AS policy_hash_key
FROM crm_enhanced_policy_relationships_csv
WHERE source_extract = 'complaint_policy_bridge.csv';
""",
  "source_table": "crm_enhanced_policy_relationships_csv",
  "created_ts": "2026-06-26 10:00:00.000000",
  "updated_ts": "2026-06-26 10:00:00.000000"
}

link_complaint_regulation_9 =  {
  "product_id": "9",
  "vault_object_id": "link_complaint_regulation_9",
  "object_type": "link",
  "target_table": "link_complaint_regulation",
  "record_source": "select origin_sys from crm_enhanced_policy_relationships_csv",
  "process_order": "2",
  "merge_keys": "complaint_regulation_hash_key",
  "build_sql": f"""
SELECT DISTINCT
    md5(concat( MD5(CONCAT(origin_sys, src_complaint_id)),MD5(CONCAT(origin_sys, src_regulation_id))))AS complaint_regulation_hash_key,
    CAST(pull_ts AS timestamp) AS load_date,
    origin_sys AS record_source,
    MD5(CONCAT(origin_sys, src_complaint_id)) AS complaint_hash_key,
    MD5(CONCAT(origin_sys, src_regulation_id)) AS regulation_hash_key
FROM crm_enhanced_policy_relationships_csv
WHERE source_extract = 'complaint_regulation_bridge.csv';
""",
  "source_table": "crm_enhanced_policy_relationships_csv",
  "created_ts": "2026-06-26 10:00:00.000000",
  "updated_ts": "2026-06-26 10:00:00.000000"
}

link_insured_object_home_9 =  {
  "product_id": "9",
  "vault_object_id": "link_insured_object_home_9",
  "object_type": "link",
  "target_table": "link_insured_object_home",
  "record_source": "select origin_sys from crm_enhanced_policy_relationships_csv",
  "process_order": "2",
  "merge_keys": "insured_object_home_hash_key",
  "build_sql": f"""
SELECT DISTINCT
    md5(concat( MD5(CONCAT(origin_sys, src_insured_object_id)),MD5(CONCAT(origin_sys, src_home_id))))AS insured_object_home_hash_key,
    CAST(pull_ts AS timestamp) AS load_date,
    origin_sys AS record_source,
    MD5(CONCAT(origin_sys, src_insured_object_id)) AS insured_object_hash_key,
    MD5(CONCAT(origin_sys, src_home_id)) AS home_hash_key
FROM crm_enhanced_policy_relationships_csv
WHERE source_extract = 'insured_object_home_bridge.csv';
""",
  "source_table": "crm_enhanced_policy_relationships_csv",
  "created_ts": "2026-06-26 10:00:00.000000",
  "updated_ts": "2026-06-26 10:00:00.000000"
}

link_insured_object_motor_9 =  {
  "product_id": "9",
  "vault_object_id": "link_insured_object_motor_9",
  "object_type": "link",
  "target_table": "link_insured_object_motor",
  "record_source": "select origin_sys from crm_enhanced_policy_relationships_csv",
  "process_order": "2",
  "merge_keys": "insured_object_motor_hash_key",
  "build_sql": f"""
SELECT DISTINCT
    md5(concat( MD5(CONCAT(origin_sys, src_insured_object_id)),MD5(CONCAT(origin_sys, src_motor_id))))AS insured_object_motor_hash_key,
    CAST(pull_ts AS timestamp) AS load_date,
    origin_sys AS record_source,
    MD5(CONCAT(origin_sys, src_insured_object_id)) AS insured_object_hash_key,
    MD5(CONCAT(origin_sys, src_motor_id)) AS motor_hash_key
FROM crm_enhanced_policy_relationships_csv
WHERE source_extract = 'insured_object_motor_bridge.csv';
""",
  "source_table": "crm_enhanced_policy_relationships_csv",
  "created_ts": "2026-06-26 10:00:00.000000",
  "updated_ts": "2026-06-26 10:00:00.000000"
}

link_policy_broker_9 =  {
  "product_id": "9",
  "vault_object_id": "link_policy_broker_9",
  "object_type": "link",
  "target_table": "link_policy_broker",
  "record_source": "select origin_sys from crm_enhanced_policy_relationships_csv",
  "process_order": "2",
  "merge_keys": "policy_broker_hash_key",
  "build_sql": f"""
SELECT DISTINCT
    md5(concat( MD5(CONCAT(origin_sys, src_policy_id)),MD5(CONCAT(origin_sys, src_agent_id))))AS policy_broker_hash_key,
    CAST(pull_ts AS timestamp) AS load_date,
    origin_sys AS record_source,
    MD5(CONCAT(origin_sys, src_policy_id)) AS policy_hash_key,
    MD5(CONCAT(origin_sys, src_agent_id)) AS broker_hash_key
FROM crm_enhanced_policy_relationships_csv
WHERE source_extract = 'policy_broker_bridge.csv';
""",
  "source_table": "crm_enhanced_policy_relationships_csv",
  "created_ts": "2026-06-26 10:00:00.000000",
  "updated_ts": "2026-06-26 10:00:00.000000"
}

link_policy_channel_9 =  {
  "product_id": "9",
  "vault_object_id": "link_policy_channel_9",
  "object_type": "link",
  "target_table": "link_policy_channel",
  "record_source": "select origin_sys from crm_enhanced_policy_relationships_csv",
  "process_order": "2",
  "merge_keys": "policy_channel_hash_key",
  "build_sql": f"""
SELECT DISTINCT
    md5(concat( MD5(CONCAT(origin_sys, src_policy_id)),MD5(CONCAT(origin_sys, src_channel_id))))AS policy_channel_hash_key,
    CAST(pull_ts AS timestamp) AS load_date,
    origin_sys AS record_source,
    MD5(CONCAT(origin_sys, src_policy_id)) AS policy_hash_key,
    MD5(CONCAT(origin_sys, src_channel_id)) AS channel_hash_key
FROM crm_enhanced_policy_relationships_csv
WHERE source_extract = 'policy_channel_bridge.csv';
""",
  "source_table": "crm_enhanced_policy_relationships_csv",
  "created_ts": "2026-06-26 10:00:00.000000",
  "updated_ts": "2026-06-26 10:00:00.000000"
}

link_policy_insured_object_9 =  {
  "product_id": "9",
  "vault_object_id": "link_policy_insured_object_9",
  "object_type": "link",
  "target_table": "link_policy_insured_object",
  "record_source": "select origin_sys from crm_enhanced_policy_relationships_csv",
  "process_order": "2",
  "merge_keys": "policy_insured_object_hash_key",
  "build_sql": f"""
SELECT DISTINCT
    md5(concat( MD5(CONCAT(origin_sys, src_policy_id)),MD5(CONCAT(origin_sys, src_insured_object_id))))AS policy_insured_object_hash_key,
    CAST(pull_ts AS timestamp) AS load_date,
    origin_sys AS record_source,
    MD5(CONCAT(origin_sys, src_policy_id)) AS policy_hash_key,
    MD5(CONCAT(origin_sys, src_insured_object_id)) AS insured_object_hash_key
FROM crm_enhanced_policy_relationships_csv
WHERE source_extract = 'policy_insured_object_bridge.csv';
""",
  "source_table": "crm_enhanced_policy_relationships_csv",
  "created_ts": "2026-06-26 10:00:00.000000",
  "updated_ts": "2026-06-26 10:00:00.000000"
}

link_policy_override_9 =  {
  "product_id": "9",
  "vault_object_id": "link_policy_override_9",
  "object_type": "link",
  "target_table": "link_policy_override",
  "record_source": "select origin_sys from crm_enhanced_policy_relationships_csv",
  "process_order": "2",
  "merge_keys": "policy_override_hash_key",
  "build_sql": f"""
SELECT DISTINCT
    md5(concat( MD5(CONCAT(origin_sys, src_policy_id)),MD5(CONCAT(origin_sys, src_override_id))))AS policy_override_hash_key,
    CAST(pull_ts AS timestamp) AS load_date,
    origin_sys AS record_source,
    MD5(CONCAT(origin_sys, src_policy_id)) AS policy_hash_key,
    MD5(CONCAT(origin_sys, src_override_id)) AS override_hash_key
FROM crm_enhanced_policy_relationships_csv
WHERE source_extract = 'policy_override_bridge.csv';
""",
  "source_table": "crm_enhanced_policy_relationships_csv",
  "created_ts": "2026-06-26 10:00:00.000000",
  "updated_ts": "2026-06-26 10:00:00.000000"
}

link_quote_broker_9 =  {
  "product_id": "9",
  "vault_object_id": "link_quote_broker_9",
  "object_type": "link",
  "target_table": "link_quote_broker",
  "record_source": "select origin_sys from crm_enhanced_policy_relationships_csv",
  "process_order": "2",
  "merge_keys": "quote_broker_hash_key",
  "build_sql": f"""
SELECT DISTINCT
    md5(concat( MD5(CONCAT(origin_sys, src_quote_id)),MD5(CONCAT(origin_sys, src_agent_id))))AS quote_broker_hash_key,
    CAST(pull_ts AS timestamp) AS load_date,
    origin_sys AS record_source,
    MD5(CONCAT(origin_sys, src_quote_id)) AS quote_hash_key,
    MD5(CONCAT(origin_sys, src_agent_id)) AS broker_hash_key
FROM crm_enhanced_policy_relationships_csv
WHERE source_extract = 'quote_broker_bridge.csv';
""",
  "source_table": "crm_enhanced_policy_relationships_csv",
  "created_ts": "2026-06-26 10:00:00.000000",
  "updated_ts": "2026-06-26 10:00:00.000000"
}

link_quote_channel_9 =  {
  "product_id": "9",
  "vault_object_id": "link_quote_channel_9",
  "object_type": "link",
  "target_table": "link_quote_channel",
  "record_source": "select origin_sys from crm_enhanced_policy_relationships_csv",
  "process_order": "2",
  "merge_keys": "quote_channel_hash_key",
  "build_sql": f"""
SELECT DISTINCT
    md5(concat( MD5(CONCAT(origin_sys, src_quote_id)),MD5(CONCAT(origin_sys, src_channel_id))))AS quote_channel_hash_key,
    CAST(pull_ts AS timestamp) AS load_date,
    origin_sys AS record_source,
    MD5(CONCAT(origin_sys, src_quote_id)) AS quote_hash_key,
    MD5(CONCAT(origin_sys, src_channel_id)) AS channel_hash_key
FROM crm_enhanced_policy_relationships_csv
WHERE  source_extract = 'quote_channel_bridge.csv';
""",
  "source_table": "crm_enhanced_policy_relationships_csv",
  "created_ts": "2026-06-26 10:00:00.000000",
  "updated_ts": "2026-06-26 10:00:00.000000"
}

# %%
link_details = {
    "process_order": "2",
    "status": {
        "link_person_natural_person_9": {"config": link_person_natural_person_9, "is_active": True},
        "link_person_legal_person_9": {"config": link_person_legal_person_9, "is_active": True},
        "link_person_contact_9": {"config": link_person_contact_9, "is_active": True},
        "link_person_identities_9": {"config": link_person_identities_9, "is_active": True},
        "link_person_address_9": {"config": link_person_address_9, "is_active": True},
        "link_person_consent_9": {"config": link_person_consent_9, "is_active": True},
        "link_person_marketing_preference_9": {"config": link_person_marketing_preference_9, "is_active": True},
        "link_person_marketing_engagement_9": {"config": link_person_marketing_engagement_9, "is_active": True},
        "link_person_lead_9": {"config": link_person_lead_9, "is_active": True},
        "link_person_account_9": {"config": link_person_account_9, "is_active": True},
        "link_customer_person_9": {"config": link_customer_person_9, "is_active": True},
        "link_customer_lead_9": {"config": link_customer_lead_9, "is_active": True},
        "link_quote_person_9": {"config": link_quote_person_9, "is_active": True},
        "link_quote_product_9": {"config": link_quote_product_9, "is_active": True},
        "link_policy_customer_9": {"config": link_policy_customer_9, "is_active": True},
        "link_policy_product_9": {"config": link_policy_product_9, "is_active": True},
        "link_policy_quote_9": {"config": link_policy_quote_9, "is_active": True},
        "link_broker_person_9": {"config": link_broker_person_9, "is_active": True},
        "link_person_campaign_9": {"config": link_person_campaign_9, "is_active": True},
        "link_claim_policy_9": {"config": link_claim_policy_9, "is_active": True},
        "link_complaint_policy_9": {"config": link_complaint_policy_9, "is_active": True},
        "link_complaint_regulation_9": {"config": link_complaint_regulation_9, "is_active": True},
        "link_insured_object_home_9": {"config": link_insured_object_home_9, "is_active": True},
        "link_insured_object_motor_9": {"config": link_insured_object_motor_9, "is_active": True},
        "link_policy_broker_9": {"config": link_policy_broker_9, "is_active": True},
        "link_policy_channel_9": {"config": link_policy_channel_9, "is_active": True},
        "link_policy_insured_object_9": {"config": link_policy_insured_object_9, "is_active": True},
        "link_policy_override_9": {"config": link_policy_override_9, "is_active": True},
        "link_quote_broker_9": {"config": link_quote_broker_9, "is_active": True},
        "link_quote_channel_9": {"config": link_quote_channel_9, "is_active": True},
    }
}

# %%
from collections import OrderedDict

active_configs = []
process_order = link_details["process_order"]
# Use OrderedDict to preserve order as in link_details["status"]
for k, v in OrderedDict(link_details["status"]).items():
    if v["is_active"]:
        config = v["config"].copy()
        config["process_order"] = str(process_order)
        active_configs.append(config)
df = spark.createDataFrame(active_configs)
display(df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>build_sql</th><th>created_ts</th><th>merge_keys</th><th>object_type</th><th>process_order</th><th>product_id</th><th>record_source</th><th>source_table</th><th>target_table</th><th>updated_ts</th><th>vault_object_id</th></tr></thead><tbody><tr><td>
# with combined as (
# SELECT DISTINCT
#     md5(concat( MD5(CONCAT(origin_sys, party_ref)),MD5(CONCAT(origin_sys, natural_ref))))AS person_natural_person_hash_key,
#     CAST(pull_ts AS timestamp) AS load_date,
#     origin_sys AS record_source,
#     MD5(CONCAT(origin_sys, party_ref)) AS person_hash_key,
#     MD5(CONCAT(origin_sys, natural_ref)) AS natural_person_hash_key
# FROM crm_party_master_csv
# WHERE where party_kind = 'NATURAL'
# UNION ALL
# SELECT DISTINCT
#     md5(concat( MD5(CONCAT(origin_sys, person_id)),MD5(CONCAT(origin_sys, person_id))))AS person_natural_person_hash_key,
#     CAST(pull_ts AS timestamp) AS load_date,
#     origin_sys AS record_source,
#     MD5(CONCAT(origin_sys, person_id)) AS person_hash_key,
#     MD5(CONCAT(origin_sys, person_id)) AS natural_person_hash_key
# FROM sap_person_db
# WHERE person_type = 'NATURAL')
# select distinct * from combined;
# </td><td>2026-06-26 10:00:00.000000</td><td>person_natural_person_hash_key</td><td>link</td><td>2</td><td>9</td><td>select origin_sys from crm_party_master_csv union all select origin_sys from sap_person_db</td><td>crm_party_master_csv, sap_person_db</td><td>link_person_natural_person</td><td>2026-06-26 10:00:00.000000</td><td>link_person_natural_person_9</td></tr><tr><td>
# with combined as (
# SELECT DISTINCT
#     md5(concat( MD5(CONCAT(origin_sys, party_ref)),MD5(CONCAT(origin_sys, legal_ref))))AS person_legal_person_hash_key,
#     CAST(pull_ts AS timestamp) AS load_date,
#     origin_sys AS record_source,
#     MD5(CONCAT(origin_sys, party_ref)) AS person_hash_key,
#     MD5(CONCAT(origin_sys, legal_ref)) AS legal_person_hash_key
# FROM crm_party_master_csv
# WHERE where party_kind = 'LEGAL'
# UNION ALL
# SELECT DISTINCT
#     md5(concat( MD5(CONCAT(origin_sys, person_id)),MD5(CONCAT(origin_sys, person_id))))AS person_legal_person_hash_key,
#     CAST(pull_ts AS timestamp) AS load_date,
#     origin_sys AS record_source,
#     MD5(CONCAT(origin_sys, person_id)) AS person_hash_key,
#     MD5(CONCAT(origin_sys, person_id)) AS legal_person_hash_key
# FROM sap_person_db
# WHERE person_type = 'LEGAL')
# select distinct * from combined;
# </td><td>2026-06-26 10:00:00.000000</td><td>person_legal_person_hash_key</td><td>link</td><td>2</td><td>9</td><td>select origin_sys from crm_party_master_csv union all select origin_sys from sap_person_db</td><td>crm_party_master_csv, sap_person_db</td><td>link_person_legal_person</td><td>2026-06-26 10:00:00.000000</td><td>link_person_legal_person_9</td></tr><tr><td>
# SELECT DISTINCT
#     md5(concat( MD5(CONCAT(origin_sys, party_ref)),MD5(CONCAT(origin_sys, contact_ref))))AS person_contact_hash_key,
#     CAST(pull_ts AS timestamp) AS load_date,
#     origin_sys AS record_source,
#     MD5(CONCAT(origin_sys, party_ref)) AS person_hash_key,
#     MD5(CONCAT(origin_sys,contact_ref)) AS contact_hash_key
# FROM crm_contact_point_csv;
# </td><td>2026-06-26 10:00:00.000000</td><td>person_contact_hash_key</td><td>link</td><td>2</td><td>9</td><td>select origin_sys from crm_contact_point_csv</td><td>crm_contact_point_csv</td><td>link_person_contact</td><td>2026-06-26 10:00:00.000000</td><td>link_person_contact_9</td></tr><tr><td>
# SELECT DISTINCT
#     md5(concat( MD5(CONCAT(origin_sys, party_ref)),MD5(CONCAT(origin_sys, identity_ref))))AS person_identities_hash_key,
#     CAST(pull_ts AS timestamp) AS load_date,
#     origin_sys AS record_source,
#     MD5(CONCAT(origin_sys, party_ref)) AS person_hash_key,
#     MD5(CONCAT(origin_sys,identity_ref)) AS identities_hash_key
# FROM crm_identity_registry_csv;
# </td><td>2026-06-26 10:00:00.000000</td><td>person_identities_hash_key</td><td>link</td><td>2</td><td>9</td><td>select origin_sys from crm_identity_registry_csv</td><td>crm_identity_registry_csv</td><td>link_person_identities</td><td>2026-06-26 10:00:00.000000</td><td>link_person_identities_9</td></tr><tr><td>
# with combined as (
# SELECT DISTINCT
#     md5(concat( MD5(CONCAT(origin_sys, party_ref)),MD5(CONCAT(origin_sys, address_ref))))AS person_address_hash_key,
#     CAST(pull_ts AS timestamp) AS load_date,
#     origin_sys AS record_source,
#     MD5(CONCAT(origin_sys, party_ref)) AS person_hash_key,
#     MD5(CONCAT(origin_sys,address_ref)) AS address_hash_key
# FROM crm_address_book_csv
# UNION ALL
# SELECT DISTINCT
#     md5(concat( MD5(CONCAT(origin_sys, src_person_id)),MD5(CONCAT(origin_sys, src_address_id))))AS person_address_hash_key,
#     CAST(pull_ts AS timestamp) AS load_date,
#     origin_sys AS record_source,
#     MD5(CONCAT(origin_sys, src_person_id)) AS person_hash_key,
#     MD5(CONCAT(origin_sys,src_address_id)) AS address_hash_key
# FROM crm_enhanced_person_relationships_csv
# WHERE source_extract = 'person_address_bridge.csv'
# UNION ALL
# SELECT DISTINCT
#     md5(concat( MD5(CONCAT(origin_sys, person_id)),MD5(CONCAT(origin_sys, address_id))))AS person_address_hash_key,
#     CAST(pull_ts AS timestamp) AS load_date,
#     origin_sys AS record_source,
#     MD5(CONCAT(origin_sys, person_id)) AS person_hash_key,
#     MD5(CONCAT(origin_sys,address_id)) AS address_hash_key
# FROM sap_address_db)
# select distinct * from combined;
# </td><td>2026-06-26 10:00:00.000000</td><td>person_address_hash_key</td><td>link</td><td>2</td><td>9</td><td>select origin_sys from crm_address_book_csv union all select origin_sys from crm_enhanced_person_relationships_csv union all select origin_sys from sap_address_db</td><td>crm_address_book_csv, crm_enhanced_person_relationships_csv, sap_address_db</td><td>link_person_address</td><td>2026-06-26 10:00:00.000000</td><td>link_person_address_9</td></tr><tr><td>
# SELECT DISTINCT
#     md5(concat( MD5(CONCAT(origin_sys, party_ref)),MD5(CONCAT(origin_sys, consent_ref))))AS person_consent_hash_key,
#     CAST(pull_ts AS timestamp) AS load_date,
#     origin_sys AS record_source,
#     MD5(CONCAT(origin_sys, party_ref)) AS person_hash_key,
#     MD5(CONCAT(origin_sys,consent_ref)) AS consent_hash_key
# FROM crm_consent_snapshot_csv;
# </td><td>2026-06-26 10:00:00.000000</td><td>person_consent_hash_key</td><td>link</td><td>2</td><td>9</td><td>select origin_sys from crm_consent_snapshot_csv</td><td>crm_consent_snapshot_csv</td><td>link_person_consent</td><td>2026-06-26 10:00:00.000000</td><td>link_person_consent_9</td></tr><tr><td>
# SELECT DISTINCT
#     md5(concat( MD5(CONCAT(origin_sys, party_ref)),MD5(CONCAT(origin_sys, preference_ref))))AS person_marketing_preference_hash_key,
#     CAST(pull_ts AS timestamp) AS load_date,
#     origin_sys AS record_source,
#     MD5(CONCAT(origin_sys, party_ref)) AS person_hash_key,
#     MD5(CONCAT(origin_sys,preference_ref)) AS marketing_preference_hash_key
# FROM crm_comm_preference_csv;
# </td><td>2026-06-26 10:00:00.000000</td><td>person_marketing_preference_hash_key</td><td>link</td><td>2</td><td>9</td><td>select origin_sys from crm_comm_preference_csv</td><td>crm_comm_preference_csv</td><td>link_person_marketing_preference</td><td>2026-06-26 10:00:00.000000</td><td>link_person_marketing_preference_9</td></tr><tr><td>
# SELECT DISTINCT
#     md5(concat( MD5(CONCAT(origin_sys, party_ref)),MD5(CONCAT(origin_sys, engagement_ref))))AS person_marketing_engagement_hash_key,
#     CAST(pull_ts AS timestamp) AS load_date,
#     origin_sys AS record_source,
#     MD5(CONCAT(origin_sys, party_ref)) AS person_hash_key,
#     MD5(CONCAT(origin_sys,engagement_ref)) AS marketing_engagement_hash_key
# FROM crm_campaign_touch_csv;
# </td><td>2026-06-26 10:00:00.000000</td><td>person_marketing_engagement_hash_key</td><td>link</td><td>2</td><td>9</td><td>select origin_sys from
