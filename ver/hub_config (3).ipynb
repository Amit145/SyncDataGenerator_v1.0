# %%
hub_person_9 =  {
  "product_id": "9",
  "vault_object_id": "hub_person_9",
  "object_type": "hub",
  "target_table": "hub_person",
  "record_source": "select origin_sys from crm_party_master_csv union all select origin_sys from sap_person_db",
  "process_order": "1",
  "merge_keys": "person_hash_key",
  "build_sql": f"""
with combined as (
SELECT DISTINCT
    MD5(CONCAT(origin_sys, party_ref)) AS person_hash_key,
    CAST(pull_ts AS timestamp) AS load_date,
    origin_sys AS record_source,
    party_ref AS person_id
FROM crm_party_master_csv
UNION ALL
SELECT DISTINCT
    MD5(CONCAT(origin_sys, person_id)) AS person_hash_key,
    CAST(pull_ts AS timestamp) AS load_date,
    origin_sys AS record_source,
    person_id AS person_id
FROM sap_person_db)
select distinct * from combined;
""",
  "source_table": "crm_party_master_csv, sap_person_db",
  "created_ts": "2026-06-26 10:00:00.000000",
  "updated_ts": "2026-06-26 10:00:00.000000"
}

hub_natural_person_9 =  {
  "product_id": "9",
  "vault_object_id": "hub_natural_person_9",
  "object_type": "hub",
  "target_table": "hub_natural_person",
  "record_source": "select origin_sys from crm_party_master_csv union all select origin_sys from sap_person_db",
  "process_order": "1",
  "merge_keys": "person_hash_key",
  "build_sql": f"""
with combined as (
SELECT DISTINCT
    MD5(CONCAT(origin_sys, natural_ref)) AS natural_person_hash_key,
    CAST(pull_ts AS timestamp) AS load_date,
    origin_sys AS record_source,
    natural_ref AS natural_person_id
FROM crm_party_master_csv
WHERE party_kind = 'NATURAL'
UNION ALL
SELECT DISTINCT
    MD5(CONCAT(origin_sys, person_id)) AS natural_person_hash_key,
    CAST(pull_ts AS timestamp) AS load_date,
    origin_sys AS record_source,
    person_id AS natural_person_id
FROM sap_person_db
WHERE person_type = 'NATURAL')

select distinct * from combined;
""",
  "source_table": "crm_party_master_csv, sap_person_db",
  "created_ts": "2026-06-26 10:00:00.000000",
  "updated_ts": "2026-06-26 10:00:00.000000"
}

hub_legal_person_9 =  {
  "product_id": "9",
  "vault_object_id": "hub_legal_person_9",
  "object_type": "hub",
  "target_table": "hub_legal_person",
  "record_source": "select origin_sys from crm_party_master_csv union all select origin_sys from sap_person_db",
  "process_order": "1",
  "merge_keys": "person_hash_key",
  "build_sql": f"""
with combined as (
SELECT DISTINCT
    MD5(CONCAT(origin_sys, legal_ref)) AS legal_person_hash_key,
    CAST(pull_ts AS timestamp) AS load_date,
    origin_sys AS record_source,
    natural_ref AS legal_person_id
FROM crm_party_master_csv
WHERE party_kind = 'LEGAL'
UNION ALL
SELECT DISTINCT
    MD5(CONCAT(origin_sys, person_id)) AS legal_person_hash_key,
    CAST(pull_ts AS timestamp) AS load_date,
    origin_sys AS record_source,
    person_id AS legal_person_id
FROM sap_person_db
WHERE person_type = 'LEGAL')

select distinct * from combined;
""",
  "source_table": "crm_party_master_csv, sap_person_db",
  "created_ts": "2026-06-26 10:00:00.000000",
  "updated_ts": "2026-06-26 10:00:00.000000"
}

hub_contact_9 =  {
  "product_id": "9",
  "vault_object_id": "hub_contact_9",
  "object_type": "hub",
  "target_table": "hub_contact",
  "record_source": "select origin_sys from crm_contact_point_csv",
  "process_order": "1",
  "merge_keys": "contact_hash_key",
  "build_sql": f"""
SELECT DISTINCT
    MD5(CONCAT(origin_sys, contact_ref)) AS contact_hash_key,
    CAST(pull_ts AS timestamp) AS load_date,
    origin_sys AS record_source,
    contact_ref AS contact_id
FROM crm_contact_point_csv;
""",
  "source_table": "crm_contact_point_csv",
  "created_ts": "2026-06-26 10:00:00.000000",
  "updated_ts": "2026-06-26 10:00:00.000000"
}

hub_identities_9 =  {
  "product_id": "9",
  "vault_object_id": "hub_identities_9",
  "object_type": "hub",
  "target_table": "hub_identities",
  "record_source": "select origin_sys from crm_identity_registry_csv",
  "process_order": "1",
  "merge_keys": "identities_hash_key",
  "build_sql": f"""
SELECT DISTINCT
    MD5(CONCAT(origin_sys, identity_ref)) AS identities_hash_key,
    CAST(pull_ts AS timestamp) AS load_date,
    origin_sys AS record_source,
    identity_ref AS identities_id
FROM crm_identity_registry_csv;
""",
  "source_table": "crm_identity_registry_csv",
  "created_ts": "2026-06-26 10:00:00.000000",
  "updated_ts": "2026-06-26 10:00:00.000000"
}

hub_address_9 =  {
  "product_id": "9",
  "vault_object_id": "hub_address_9",
  "object_type": "hub",
  "target_table": "hub_address",
  "record_source": "select origin_sys from crm_address_book_csv union all select origin_sys from crm_enhanced_address_book_csv union all select origin_sys from sap_address_db",
  "process_order": "1",
  "merge_keys": "address_hash_key",
  "build_sql": f"""
with combined as (
SELECT DISTINCT
    MD5(CONCAT(origin_sys, address_ref)) AS address_hash_key,
    CAST(pull_ts AS timestamp) AS load_date,
    origin_sys AS record_source,
    address_ref AS address_id
FROM crm_address_book_csv
UNION ALL
SELECT DISTINCT
    MD5(CONCAT(origin_sys, src_address_id)) AS address_hash_key,
    CAST(pull_ts AS timestamp) AS load_date,
    origin_sys AS record_source,
    src_address_id AS address_id
FROM crm_enhanced_address_book_csv
UNION ALL
SELECT DISTINCT
    MD5(CONCAT(origin_sys, address_id)) AS address_hash_key,
    CAST(pull_ts AS timestamp) AS load_date,
    origin_sys AS record_source,
    address_id AS address_id
FROM sap_address_db)
select distinct * from combined;
""",
  "source_table": "crm_address_book_csv, crm_enhanced_address_book_csv, sap_address_db",
  "created_ts": "2026-06-26 10:00:00.000000",
  "updated_ts": "2026-06-26 10:00:00.000000"
}

hub_consent_9 =  {
  "product_id": "9",
  "vault_object_id": "hub_consent_9",
  "object_type": "hub",
  "target_table": "hub_consent",
  "record_source": "select origin_sys from crm_consent_snapshot_csv",
  "process_order": "1",
  "merge_keys": "consent_hash_key",
  "build_sql": f"""
SELECT DISTINCT
    MD5(CONCAT(origin_sys, consent_ref)) AS consent_hash_key,
    CAST(pull_ts AS timestamp) AS load_date,
    origin_sys AS record_source,
    consent_ref AS consent_id
FROM crm_consent_snapshot_csv;
""",
  "source_table": "crm_consent_snapshot_csv",
  "created_ts": "2026-06-26 10:00:00.000000",
  "updated_ts": "2026-06-26 10:00:00.000000"
}

hub_marketing_preference_9 =  {
  "product_id": "9",
  "vault_object_id": "hub_marketing_preference_9",
  "object_type": "hub",
  "target_table": "hub_marketing_preference",
  "record_source": "select origin_sys from crm_comm_preference_csv",
  "process_order": "1",
  "merge_keys": "marketing_preference_hash_key",
  "build_sql": f"""
SELECT DISTINCT
    MD5(CONCAT(origin_sys, preference_ref)) AS marketing_preference_hash_key,
    CAST(pull_ts AS timestamp) AS load_date,
    origin_sys AS record_source,
    preference_ref AS marketing_preference_id
FROM crm_comm_preference_csv;
""",
  "source_table": "crm_comm_preference_csv",
  "created_ts": "2026-06-26 10:00:00.000000",
  "updated_ts": "2026-06-26 10:00:00.000000"
}

hub_marketing_engagement_9 =  {
  "product_id": "9",
  "vault_object_id": "hub_marketing_engagement_9",
  "object_type": "hub",
  "target_table": "hub_marketing_engagement",
  "record_source": "select origin_sys from crm_campaign_touch_csv",
  "process_order": "1",
  "merge_keys": "marketing_engagement_hash_key",
  "build_sql": f"""
SELECT DISTINCT
    MD5(CONCAT(origin_sys, engagement_ref)) AS marketing_engagement_hash_key,
    CAST(pull_ts AS timestamp) AS load_date,
    origin_sys AS record_source,
    engagement_ref AS marketing_engagement_id
FROM crm_campaign_touch_csv;
""",
  "source_table": "crm_campaign_touch_csv",
  "created_ts": "2026-06-26 10:00:00.000000",
  "updated_ts": "2026-06-26 10:00:00.000000"
}

hub_lead_9 =  {
  "product_id": "9",
  "vault_object_id": "hub_lead_9",
  "object_type": "hub",
  "target_table": "hub_lead",
  "record_source": "select origin_sys from crm_lead_register_csv",
  "process_order": "1",
  "merge_keys": "lead_hash_key",
  "build_sql": f"""
SELECT DISTINCT
    MD5(CONCAT(origin_sys, lead_ref)) AS lead_hash_key,
    CAST(pull_ts AS timestamp) AS load_date,
    origin_sys AS record_source,
    lead_ref AS lead_id
FROM crm_lead_register_csv;
""",
  "source_table": "crm_lead_register_csv",
  "created_ts": "2026-06-26 10:00:00.000000",
  "updated_ts": "2026-06-26 10:00:00.000000"
}

hub_quote_9 =  {
  "product_id": "9",
  "vault_object_id": "hub_quote_9",
  "object_type": "hub",
  "target_table": "hub_quote",
  "record_source": "select origin_sys from crm_quote_register_csv",
  "process_order": "1",
  "merge_keys": "quote_hash_key",
  "build_sql": f"""
SELECT DISTINCT
    MD5(CONCAT(origin_sys, quote_ref)) AS quote_hash_key,
    CAST(pull_ts AS timestamp) AS load_date,
    origin_sys AS record_source,
    quote_ref AS quote_id
FROM crm_quote_register_csv;
""",
  "source_table": "crm_quote_register_csv",
  "created_ts": "2026-06-26 10:00:00.000000",
  "updated_ts": "2026-06-26 10:00:00.000000"
}

hub_policy_9 =  {
  "product_id": "9",
  "vault_object_id": "hub_policy_9",
  "object_type": "hub",
  "target_table": "hub_policy",
  "record_source": "select origin_sys from crm_policy_register_csv union all select origin_sys from sap_home_db union all select origin_sys from sap_motor_db",
  "process_order": "1",
  "merge_keys": "policy_hash_key",
  "build_sql": f"""
with combined as (
SELECT DISTINCT
    MD5(CONCAT(origin_sys, policy_ref)) AS policy_hash_key,
    CAST(pull_ts AS timestamp) AS load_date,
    origin_sys AS record_source,
    policy_ref AS policy_id
FROM crm_policy_register_csv
UNION ALL
SELECT DISTINCT
    MD5(CONCAT(origin_sys, policy_id)) AS policy_hash_key,
    CAST(pull_ts AS timestamp) AS load_date,
    origin_sys AS record_source,
    policy_id AS policy_id
FROM sap_home_db
UNION ALL
SELECT DISTINCT
    MD5(CONCAT(origin_sys, policy_id)) AS policy_hash_key,
    CAST(pull_ts AS timestamp) AS load_date,
    origin_sys AS record_source,
    policy_id AS policy_id
FROM sap_motor_db)
select distinct * from combined;
""",
  "source_table": "crm_policy_register_csv, sap_home_db, sap_motor_db",
  "created_ts": "2026-06-26 10:00:00.000000",
  "updated_ts": "2026-06-26 10:00:00.000000"
}

hub_account_9 =  {
  "product_id": "9",
  "vault_object_id": "hub_account_9",
  "object_type": "hub",
  "target_table": "hub_account",
  "record_source": "select origin_sys from crm_account_book_csv",
  "process_order": "1",
  "merge_keys": "account_hash_key",
  "build_sql": f"""
SELECT DISTINCT
    MD5(CONCAT(origin_sys, account_ref)) AS account_hash_key,
    CAST(pull_ts AS timestamp) AS load_date,
    origin_sys AS record_source,
    account_ref AS account_id
FROM crm_account_book_csv;
""",
  "source_table": "crm_account_book_csv",
  "created_ts": "2026-06-26 10:00:00.000000",
  "updated_ts": "2026-06-26 10:00:00.000000"
}

hub_customer_9 =  {
  "product_id": "9",
  "vault_object_id": "hub_customer_9",
  "object_type": "hub",
  "target_table": "hub_customer",
  "record_source": "select origin_sys from crm_customer_portfolio_csv",
  "process_order": "1",
  "merge_keys": "customer_hash_key",
  "build_sql": f"""
SELECT DISTINCT
    MD5(CONCAT(origin_sys, customer_ref)) AS customer_hash_key,
    CAST(pull_ts AS timestamp) AS load_date,
    origin_sys AS record_source,
    customer_ref AS customer_id
FROM crm_customer_portfolio_csv;
""",
  "source_table": "crm_customer_portfolio_csv",
  "created_ts": "2026-06-26 10:00:00.000000",
  "updated_ts": "2026-06-26 10:00:00.000000"
}

hub_product_9 =  {
  "product_id": "9",
  "vault_object_id": "hub_product_9",
  "object_type": "hub",
  "target_table": "hub_product",
  "record_source": "select origin_sys from crm_product_catalog_csv union all select origin_sys from sap_product_db union all select origin_sys from sap_home_db union all select origin_sys from sap_motor_db",
  "process_order": "1",
  "merge_keys": "product_hash_key",
  "build_sql": f"""
with combined as (
SELECT DISTINCT
    MD5(CONCAT(origin_sys, product_ref)) AS product_hash_key,
    CAST(pull_ts AS timestamp) AS load_date,
    origin_sys AS record_source,
    product_ref AS product_id
FROM crm_product_catalog_csv
UNION ALL
SELECT DISTINCT
    MD5(CONCAT(origin_sys, product_id)) AS product_hash_key,
    CAST(pull_ts AS timestamp) AS load_date,
    origin_sys AS record_source,
    product_id AS product_id
FROM sap_product_db
UNION ALL
SELECT DISTINCT
    MD5(CONCAT(origin_sys, product_id)) AS product_hash_key,
    CAST(pull_ts AS timestamp) AS load_date,
    origin_sys AS record_source,
    product_id AS product_id
FROM sap_home_db
UNION ALL
SELECT DISTINCT
    MD5(CONCAT(origin_sys, product_id)) AS product_hash_key,
    CAST(pull_ts AS timestamp) AS load_date,
    origin_sys AS record_source,
    product_id AS product_id
FROM sap_motor_db)
select distinct * from combined;
""",
  "source_table": "crm_product_catalog_csv, sap_product_db, sap_home_db, sap_motor_db",
  "created_ts": "2026-06-26 10:00:00.000000",
  "updated_ts": "2026-06-26 10:00:00.000000"
}

hub_motor_9 =  {
  "product_id": "9",
  "vault_object_id": "hub_motor_9",
  "object_type": "hub",
  "target_table": "hub_motor",
  "record_source": "select origin_sys from crm_vehicle_asset_csv union all select origin_sys from sap_motor_db",
  "process_order": "1",
  "merge_keys": "motor_hash_key",
  "build_sql": f"""
with combined as (
SELECT DISTINCT
    MD5(CONCAT(origin_sys, vehicle_ref)) AS motor_hash_key,
    CAST(pull_ts AS timestamp) AS load_date,
    origin_sys AS record_source,
    vehicle_ref AS insured_object_motor_id
FROM crm_vehicle_asset_csv
UNION ALL
SELECT DISTINCT
    MD5(CONCAT(origin_sys, motor_id)) AS motor_hash_key,
    CAST(pull_ts AS timestamp) AS load_date,
    origin_sys AS record_source,
    motor_id AS insured_object_motor_id
FROM sap_motor_db)
select distinct * from combined;
""",
  "source_table": "crm_vehicle_asset_csv, sap_motor_db",
  "created_ts": "2026-06-26 10:00:00.000000",
  "updated_ts": "2026-06-26 10:00:00.000000"
}

hub_home_9 =  {
  "product_id": "9",
  "vault_object_id": "hub_home_9",
  "object_type": "hub",
  "target_table": "hub_home",
  "record_source": "select origin_sys from crm_property_asset_csv union all select origin_sys from sap_home_db",
  "process_order": "1",
  "merge_keys": "home_hash_key",
  "build_sql": f"""
with combined as (
SELECT DISTINCT
    MD5(CONCAT(origin_sys, property_ref)) AS home_hash_key,
    CAST(pull_ts AS timestamp) AS load_date,
    origin_sys AS record_source,
    property_ref AS insured_object_home_id
FROM crm_property_asset_csv
UNION ALL
SELECT DISTINCT
    MD5(CONCAT(origin_sys, home_id)) AS home_hash_key,
    CAST(pull_ts AS timestamp) AS load_date,
    origin_sys AS record_source,
    home_id AS insured_object_home_id
FROM sap_home_db)
select distinct * from combined;
""",
  "source_table": "crm_property_asset_csv, sap_home_db",
  "created_ts": "2026-06-26 10:00:00.000000",
  "updated_ts": "2026-06-26 10:00:00.000000"
}

hub_broker_9 =  {
  "product_id": "9",
  "vault_object_id": "hub_broker_9",
  "object_type": "hub",
  "target_table": "hub_broker",
  "record_source": "select origin_sys from crm_broker_book_csv",
  "process_order": "1",
  "merge_keys": "broker_hash_key",
  "build_sql": f"""
SELECT DISTINCT
    MD5(CONCAT(origin_sys, src_agent_id)) AS broker_hash_key,
    CAST(pull_ts AS timestamp) AS load_date,
    origin_sys AS record_source,
    src_agent_id AS agent_id
FROM crm_broker_book_csv;
""",
  "source_table": "crm_broker_book_csv",
  "created_ts": "2026-06-26 10:00:00.000000",
  "updated_ts": "2026-06-26 10:00:00.000000"
}

hub_campaign_9 =  {
  "product_id": "9",
  "vault_object_id": "hub_campaign_9",
  "object_type": "hub",
  "target_table": "hub_campaign",
  "record_source": "select origin_sys from crm_campaign_register_csv",
  "process_order": "1",
  "merge_keys": "campaign_hash_key",
  "build_sql": f"""
SELECT DISTINCT
    MD5(CONCAT(origin_sys, src_campaign_id)) AS campaign_hash_key,
    CAST(pull_ts AS timestamp) AS load_date,
    origin_sys AS record_source,
    src_campaign_id AS campaign_id
FROM crm_campaign_register_csv;
""",
  "source_table": "crm_campaign_register_csv",
  "created_ts": "2026-06-26 10:00:00.000000",
  "updated_ts": "2026-06-26 10:00:00.000000"
}

hub_channel_9 =  {
  "product_id": "9",
  "vault_object_id": "hub_channel_9",
  "object_type": "hub",
  "target_table": "hub_channel",
  "record_source": "select origin_sys from crm_channel_catalog_csv",
  "process_order": "1",
  "merge_keys": "channel_hash_key",
  "build_sql": f"""
SELECT DISTINCT
    MD5(CONCAT(origin_sys, src_channel_id)) AS channel_hash_key,
    CAST(pull_ts AS timestamp) AS load_date,
    origin_sys AS record_source,
    src_channel_id AS channel_id
FROM crm_channel_catalog_csv;
""",
  "source_table": "crm_channel_catalog_csv",
  "created_ts": "2026-06-26 10:00:00.000000",
  "updated_ts": "2026-06-26 10:00:00.000000"
}

hub_claim_9 =  {
  "product_id": "9",
  "vault_object_id": "hub_claim_9",
  "object_type": "hub",
  "target_table": "hub_claim",
  "record_source": "select origin_sys from crm_claim_register_csv",
  "process_order": "1",
  "merge_keys": "claim_hash_key",
  "build_sql": f"""
SELECT DISTINCT
    MD5(CONCAT(origin_sys, src_claim_id)) AS claim_hash_key,
    CAST(pull_ts AS timestamp) AS load_date,
    origin_sys AS record_source,
    src_claim_id AS claim_id
FROM crm_claim_register_csv;
""",
  "source_table": "crm_claim_register_csv",
  "created_ts": "2026-06-26 10:00:00.000000",
  "updated_ts": "2026-06-26 10:00:00.000000"
}

hub_complaint_9 =  {
  "product_id": "9",
  "vault_object_id": "hub_complaint_9",
  "object_type": "hub",
  "target_table": "hub_complaint",
  "record_source": "select origin_sys from crm_complaint_register_csv",
  "process_order": "1",
  "merge_keys": "complaint_hash_key",
  "build_sql": f"""
SELECT DISTINCT
    MD5(CONCAT(origin_sys, src_complaint_id)) AS complaint_hash_key,
    CAST(pull_ts AS timestamp) AS load_date,
    origin_sys AS record_source,
    src_complaint_id AS complaint_id
FROM crm_complaint_register_csv;
""",
  "source_table": "crm_complaint_register_csv",
  "created_ts": "2026-06-26 10:00:00.000000",
  "updated_ts": "2026-06-26 10:00:00.000000"
}

hub_insured_object_9 =  {
  "product_id": "9",
  "vault_object_id": "hub_insured_object_9",
  "object_type": "hub",
  "target_table": "hub_insured_object",
  "record_source": "select origin_sys from crm_property_asset_csv union all select origin_sys from crm_vehicle_asset_csv",
  "process_order": "1",
  "merge_keys": "insured_object_hash_key",
  "build_sql": f"""
with combined as (
SELECT DISTINCT
    MD5(CONCAT(origin_sys, insured_object_id)) AS insured_object_hash_key,
    CAST(pull_ts AS timestamp) AS load_date,
    origin_sys AS record_source,
    insured_object_id AS insured_object_id
FROM crm_property_asset_csv
UNION ALL
SELECT DISTINCT
    MD5(CONCAT(origin_sys, insured_object_id)) AS insured_object_hash_key,
    CAST(pull_ts AS timestamp) AS load_date,
    origin_sys AS record_source,
    insured_object_id AS insured_object_id
FROM crm_vehicle_asset_csv)
select distinct * from combined;
""",
  "source_table": "crm_property_asset_csv, crm_vehicle_asset_csv",
  "created_ts": "2026-06-26 10:00:00.000000",
  "updated_ts": "2026-06-26 10:00:00.000000"
}

hub_override_9 =  {
  "product_id": "9",
  "vault_object_id": "hub_override_9",
  "object_type": "hub",
  "target_table": "hub_override",
  "record_source": "select origin_sys from crm_override_register_csv",
  "process_order": "1",
  "merge_keys": "override_hash_key",
  "build_sql": f"""
SELECT DISTINCT
    MD5(CONCAT(origin_sys, src_override_id)) AS override_hash_key,
    CAST(pull_ts AS timestamp) AS load_date,
    origin_sys AS record_source,
    src_override_id AS override_id
FROM crm_override_register_csv;
""",
  "source_table": "crm_override_register_csv",
  "created_ts": "2026-06-26 10:00:00.000000",
  "updated_ts": "2026-06-26 10:00:00.000000"
}

hub_regulation_9 =  {
  "product_id": "9",
  "vault_object_id": "hub_regulation_9",
  "object_type": "hub",
  "target_table": "hub_regulation",
  "record_source": "select origin_sys from crm_regulation_register_csv",
  "process_order": "1",
  "merge_keys": "regulation_hash_key",
  "build_sql": f"""
SELECT DISTINCT
    MD5(CONCAT(origin_sys, src_regulation_id)) AS regulation_hash_key,
    CAST(pull_ts AS timestamp) AS load_date,
    origin_sys AS record_source,
    src_regulation_id AS regulation_id
FROM crm_regulation_register_csv;
""",
  "source_table": "crm_regulation_register_csv",
  "created_ts": "2026-06-26 10:00:00.000000",
  "updated_ts": "2026-06-26 10:00:00.000000"
}

# %%
hub_details = {
    "process_order": "1",
    "status": {
        "hub_person_9": {"config": hub_person_9, "is_active": True},
        "hub_natural_person_9": {"config": hub_natural_person_9, "is_active": True},
        "hub_legal_person_9": {"config": hub_legal_person_9, "is_active": True},
        "hub_contact_9": {"config": hub_contact_9, "is_active": True},
        "hub_identities_9": {"config": hub_identities_9, "is_active": True},
        "hub_address_9": {"config": hub_address_9, "is_active": True},
        "hub_consent_9": {"config": hub_consent_9, "is_active": True},
        "hub_marketing_preference_9": {"config": hub_marketing_preference_9, "is_active": True},
        "hub_marketing_engagement_9": {"config": hub_marketing_engagement_9, "is_active": True},
        "hub_lead_9": {"config": hub_lead_9, "is_active": True},
        "hub_quote_9": {"config": hub_quote_9, "is_active": True},
        "hub_policy_9": {"config": hub_policy_9, "is_active": True},
        "hub_account_9": {"config": hub_account_9, "is_active": True},
        "hub_customer_9": {"config": hub_customer_9, "is_active": True},
        "hub_product_9": {"config": hub_product_9, "is_active": True},
        "hub_motor_9": {"config": hub_motor_9, "is_active": True},
        "hub_home_9": {"config": hub_home_9, "is_active": True},
        "hub_broker_9": {"config": hub_broker_9, "is_active": True},
        "hub_campaign_9": {"config": hub_campaign_9, "is_active": True},
        "hub_channel_9": {"config": hub_channel_9, "is_active": True},
        "hub_claim_9": {"config": hub_claim_9, "is_active": True},
        "hub_complaint_9": {"config": hub_complaint_9, "is_active": True},
        "hub_insured_object_9": {"config": hub_insured_object_9, "is_active": True},
        "hub_override_9": {"config": hub_override_9, "is_active": True},
        "hub_regulation_9": {"config": hub_regulation_9, "is_active": True},
    }
}

# %%
from collections import OrderedDict

active_configs = []
process_order = hub_details["process_order"]
# Use OrderedDict to preserve order as in hub_details["status"]
for k, v in OrderedDict(hub_details["status"]).items():
    if v["is_active"]:
        config = v["config"].copy()
        config["process_order"] = str(process_order)
        active_configs.append(config)
df = spark.createDataFrame(active_configs)
display(df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>build_sql</th><th>created_ts</th><th>merge_keys</th><th>object_type</th><th>process_order</th><th>product_id</th><th>record_source</th><th>source_table</th><th>target_table</th><th>updated_ts</th><th>vault_object_id</th></tr></thead><tbody><tr><td>
# with combined as (
# SELECT DISTINCT
#     MD5(CONCAT(origin_sys, party_ref)) AS person_hash_key,
#     CAST(pull_ts AS timestamp) AS load_date,
#     origin_sys AS record_source,
#     party_ref AS person_id
# FROM crm_party_master_csv
# UNION ALL
# SELECT DISTINCT
#     MD5(CONCAT(origin_sys, person_id)) AS person_hash_key,
#     CAST(pull_ts AS timestamp) AS load_date,
#     origin_sys AS record_source,
#     person_id AS person_id
# FROM sap_person_db)
# select distinct * from combined;
# </td><td>2026-06-26 10:00:00.000000</td><td>person_hash_key</td><td>hub</td><td>1</td><td>9</td><td>select origin_sys from crm_party_master_csv union all select origin_sys from sap_person_db</td><td>crm_party_master_csv, sap_person_db</td><td>hub_person</td><td>2026-06-26 10:00:00.000000</td><td>hub_person_9</td></tr><tr><td>
# with combined as (
# SELECT DISTINCT
#     MD5(CONCAT(origin_sys, natural_ref)) AS person_hash_key,
#     CAST(pull_ts AS timestamp) AS load_date,
#     origin_sys AS record_source,
#     natural_ref AS person_id
# FROM crm_party_master_csv
# WHERE party_kind = 'NATURAL'
# UNION ALL
# SELECT DISTINCT
#     MD5(CONCAT(origin_sys, person_id)) AS person_hash_key,
#     CAST(pull_ts AS timestamp) AS load_date,
#     origin_sys AS record_source,
#     person_id AS person_id
# FROM sap_person_db
# WHERE person_type = 'NATURAL')
#
# select distinct * from combined;
# </td><td>2026-06-26 10:00:00.000000</td><td>person_hash_key</td><td>hub</td><td>1</td><td>9</td><td>select origin_sys from crm_party_master_csv union all select origin_sys from sap_person_db</td><td>crm_party_master_csv, sap_person_db</td><td>hub_natural_person</td><td>2026-06-26 10:00:00.000000</td><td>hub_natural_person_9</td></tr><tr><td>
# with combined as (
# SELECT DISTINCT
#     MD5(CONCAT(origin_sys, legal_ref)) AS person_hash_key,
#     CAST(pull_ts AS timestamp) AS load_date,
#     origin_sys AS record_source,
#     natural_ref AS person_id
# FROM crm_party_master_csv
# WHERE party_kind = 'LEGAL'
# UNION ALL
# SELECT DISTINCT
#     MD5(CONCAT(origin_sys, person_id)) AS person_hash_key,
#     CAST(pull_ts AS timestamp) AS load_date,
#     origin_sys AS record_source,
#     person_id AS person_id
# FROM sap_person_db
# WHERE person_type = 'LEGAL')
#
# select distinct * from combined;
# </td><td>2026-06-26 10:00:00.000000</td><td>person_hash_key</td><td>hub</td><td>1</td><td>9</td><td>select origin_sys from crm_party_master_csv union all select origin_sys from sap_person_db</td><td>crm_party_master_csv, sap_person_db</td><td>hub_legal_person</td><td>2026-06-26 10:00:00.000000</td><td>hub_legal_person_9</td></tr><tr><td>
# SELECT DISTINCT
#     MD5(CONCAT(origin_sys, contact_ref)) AS contact_hash_key,
#     CAST(pull_ts AS timestamp) AS load_date,
#     origin_sys AS record_source,
#     contact_ref AS contact_id
# FROM crm_contact_point_csv;
# </td><td>2026-06-26 10:00:00.000000</td><td>contact_hash_key</td><td>hub</td><td>1</td><td>9</td><td>select origin_sys from crm_contact_point_csv</td><td>crm_contact_point_csv</td><td>hub_contact</td><td>2026-06-26 10:00:00.000000</td><td>hub_contact_9</td></tr><tr><td>
# SELECT DISTINCT
#     MD5(CONCAT(origin_sys, identity_ref)) AS identities_hash_key,
#     CAST(pull_ts AS timestamp) AS load_date,
#     origin_sys AS record_source,
#     identity_ref AS identities_id
# FROM crm_identity_registry_csv;
# </td><td>2026-06-26 10:00:00.000000</td><td>identities_hash_key</td><td>hub</td><td>1</td><td>9</td><td>select origin_sys from crm_identity_registry_csv</td><td>crm_identity_registry_csv</td><td>hub_identities</td><td>2026-06-26 10:00:00.000000</td><td>hub_identities_9</td></tr><tr><td>
# with combined as (
# SELECT DISTINCT
#     MD5(CONCAT(origin_sys, address_ref)) AS address_hash_key,
#     CAST(pull_ts AS timestamp) AS load_date,
#     origin_sys AS record_source,
#     address_ref AS address_id
# FROM crm_address_book_csv
# UNION ALL
# SELECT DISTINCT
#     MD5(CONCAT(origin_sys, src_address_id)) AS address_hash_key,
#     CAST(pull_ts AS timestamp) AS load_date,
#     origin_sys AS record_source,
#     src_address_id AS address_id
# FROM crm_enhanced_address_book_csv
# UNION ALL
# SELECT DISTINCT
#     MD5(CONCAT(origin_sys, address_id)) AS address_hash_key,
#     CAST(pull_ts AS timestamp) AS load_date,
#     origin_sys AS record_source,
#     address_id AS address_id
# FROM sap_address_db)
# select distinct * from combined;
# </td><td>2026-06-26 10:00:00.000000</td><td>address_hash_key</td><td>hub</td><td>1</td><td>9</td><td>select origin_sys from crm_address_book_csv union all select origin_sys from crm_enhanced_address_book_csv union all select origin_sys from sap_address_db</td><td>crm_address_book_csv, crm_enhanced_address_book_csv, sap_address_db</td><td>hub_address</td><td>2026-06-26 10:00:00.000000</td><td>hub_address_9</td></tr><tr><td>
# SELECT DISTINCT
#     MD5(CONCAT(origin_sys, consent_ref)) AS consent_hash_key,
#     CAST(pull_ts AS timestamp) AS load_date,
#     origin_sys AS record_source,
#     consent_ref AS consent_id
# FROM crm_consent_snapshot_csv;
# </td><td>2026-06-26 10:00:00.000000</td><td>consent_hash_key</td><td>hub</td><td>1</td><td>9</td><td>select origin_sys from crm_consent_snapshot_csv</td><td>crm_consent_snapshot_csv</td><td>hub_consent</td><td>2026-06-26 10:00:00.000000</td><td>hub_consent_9</td></tr><tr><td>
# SELECT DISTINCT
#     MD5(CONCAT(origin_sys, preference_ref)) AS marketing_preference_hash_key,
#     CAST(pull_ts AS timestamp) AS load_date,
#     origin_sys AS record_source,
#     preference_ref AS marketing_preference_id
# FROM crm_comm_preference_csv;
# </td><td>2026-06-26 10:00:00.000000</td><td>marketing_preference_hash_key</td><td>hub</td><td>1</td><td>9</td><td>select origin_sys from crm_comm_preference_csv</td><td>crm_comm_preference_csv</td><td>hub_marketing_preference</td><td>2026-06-26 10:00:00.000000</td><td>hub_marketing_preference_9</td></tr><tr><td>
# SELECT DISTINCT
#     MD5(CONCAT(origin_sys, engagement_ref)) AS marketing_engagement_hash_key,
#     CAST(pull_ts AS timestamp) AS load_date,
#     origin_sys AS record_source,
#     engagement_ref AS marketing_engagement_id
# FROM crm_campaign_touch_csv;
# </td><td>2026-06-26 10:00:00.000000</td><td>marketing_engagement_hash_key</td><td>hub</td><td>1</td><td>9</td><td>select origin_sys from crm_campaign_touch_csv</td><td>crm_campaign_touch_csv</td><td>hub_marketing_engagement</td><td>2026-06-26 10:00:00.000000</td><td>hub_marketing_engagement_9</td></tr><tr><td>
# SELECT DISTINCT
#     MD5(CONCAT(origin_sys, lead_ref)) AS lead_hash_key,
#     CAST(pull_ts AS timestamp) AS load_date,
#     origin_sys AS record_source,
#     lead_ref AS lead_id
# FROM crm_lead_register_csv;
# </td><td>2026-06-26 10:00:00.000000</td><td>lead_hash_key</td><td>hub</td><td>1</td><td>9</td><td>select origin_sys from crm_lead_register_csv</td><td>crm_lead_register_csv</td><td>hub_lead</td><td>2026-06-26 10:00:00.000000</td><td>hub_lead_9</td></tr><tr><td>
# SELECT DISTINCT
#     MD5(CONCAT(quote_ref, quote_ref)) AS quote_hash_key,
#     CAST(pull_ts AS timestamp) AS load_date,
#     origin_sys AS record_source,
#     quote_ref AS quote_id
# FROM crm_quote_register_csv;
# </td><td>2026-06-26 10:00:00.000000</td><td>quote_hash_key</td><td>hub</td><td>1</td><td>9</td><td>select origin_sys from crm_quote_register_csv</td><td>crm_quote_register_csv</td><td>hub_quote</td><td>2026-06-26 10:00:00.000000</td><td>hub_quote_9</td></tr><tr><td>
# with combined as (
# SELECT DISTINCT
#     MD5(CONCAT(origin_sys, policy_ref)) AS policy_hash_key,
#     CAST(pull_ts AS timestamp) AS load_date,
#     origin_sys AS reco
